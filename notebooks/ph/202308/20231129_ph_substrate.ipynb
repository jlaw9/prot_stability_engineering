# %% [markdown]
# ### 2023-11-29 Get the substrate for each ph optimum from BRENDA
# * 1. Get the substrate for proteins I already curated
# * 2. Assign the substrate based on papers where it's listed
#       - if Kms are listed, just use the substrate with the lowest Km(?)
# * 3. For papers/organisms where multiple substrates are listed, need to review manually
# * 4. Sabio RK has substrates listed. About 1/4 of uniprot IDs overlap with BRENDA
# * 5. RetroBioCat has the substrate curated along with the pH of the reaction
#
# TODO UniProt pH data

# %%
import numpy as np
import pandas as pd
import os
import itertools
from typing import List, Tuple
import string
from pathlib import Path
from tqdm.auto import tqdm, trange

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
base_dir = Path("/projects/robustmicrob/jlaw/projects/prot_stability_engineering")
inputs_dir = base_dir / "inputs/brenda"

# %% [markdown]
# ### Location of manually curated files
# - inputs/brenda/manual_annot
# - ph_range: 20230907_ph_range_redox_ann.csv, 20230907_ph_range_multi_prot_ec_reactions.csv
# - ph_opt_redox: manual_annot/20230907_ph_opt_redox_ann.csv
#   - only has oxidation/reduction assignment, not substrate info
# - Google sheet with manually reviewed info:
# [20230907_ph_range_multi_prot_ec_reactions](https://docs.google.com/spreadsheets/d/1bEWh-YTyQF_R0x4COMM9Q1CX-Uzkd5dmIDqM26JnwHQ/edit?usp=sharing)

# %%
multi_file = inputs_dir / "manual_annot/20230907_ph_range_multi_prot_ec_reactions.csv"
data_multi = pd.read_csv(multi_file)
print(len(data_multi))
data_multi.head(2)
# Out:
# 876
#    index    ec_num  ph_min ph_max  \
# 0   3270  4.1.2.42     5.0     10
# 1   3271  4.1.2.42     6.0    9.5
#
#                                             comments     organism  uniprot_id  \
# 0  pH 5.0: about 55% of maximal activity, pH 10.0...  Delftia sp.  A0A031HCH9
# 1  pH 6.0: about 65% of maximal activity, pH 9.5:...  Delftia sp.  A0A031HCH9
#
#       ref                                       notes  ec_uniprot_grp  \
# 0  747468  {'aldol addition', 'retro-aldol addition'}              89
# 1  747468                    {'retro-aldol addition'}              89
#
#         substrates                    products reaction_type substrates_rev  \
# 0  {'D-threonine'}  {'glycine + acetaldehyde'}             -            NaN
# 1  {'D-threonine'}  {'glycine + acetaldehyde'}             -            NaN
#
#   enzyme_immobilization  condition to_fix notes.1
# 0                   NaN        NaN    NaN     NaN
# 1                   NaN        NaN    NaN     NaN

# %%
redox_ann_file = inputs_dir / "manual_annot/20230907_ph_range_redox_ann.csv"
data_redox = pd.read_csv(redox_ann_file)
print(len(data_redox))
data_redox.head(2)
# Out:
# 725
#    index                                            ec_link  \
# 0     13  https://www.brenda-enzymes.org/enzyme.php?ecno...
# 1     16  https://www.brenda-enzymes.org/enzyme.php?ecno...
#
#                                             ref_link   ec_num  \
# 0  https://www.brenda-enzymes.org/literature.php?...  1.1.1.1
# 1  https://www.brenda-enzymes.org/literature.php?...  1.1.1.1
#
#                     name  ph_min ph_max  \
# 0  alcohol dehydrogenase     7.0    9.6
# 1  alcohol dehydrogenase     9.6   11.5
#
#                                             comments          organism  \
# 0  pH 7.0: about 70% of maximal activity, pH 9.6:...  Aeropyrum pernix
# 1  pH 9.5: about 40% of maximal activity, pH 11.5...  Aeropyrum pernix
#
#   uniprot_id  ...                                         substrates  \
# 0     Q9Y9P9  ...  {'1-propanol + NAD+', '2-propanol + NAD+', 'et...
# 1     Q9Y9P9  ...  {'1-propanol + NAD+', '2-propanol + NAD+', 'et...
#
#                                             products  \
# 0  {'acetaldehyde + NADH + H+', '4-methoxybenzald...
# 1  {'acetaldehyde + NADH + H+', '4-methoxybenzald...
#
#                           notes reaction_type substrates_rev condition  \
# 0  {'reduction of 2-pentanone'}     reduction    2-pentanone       NaN
# 1   {'oxidation of 2-pentanol'}     oxidation    2-pentanone       NaN
#
#    to_fix notes.1          rxn_type_guess  \
# 0     NaN     NaN  oxidation_or_reduction
# 1     NaN     NaN  oxidation_or_reduction
#
#                                       all_substrates
# 0  {'benzyl alcohol', '4-methoxyphenylacetone', '...
# 1  {'benzyl alcohol', '4-methoxyphenylacetone', '...
#
# [2 rows x 21 columns]

# %%
# "rev" stands for "reviewed"
data_multi.substrates_rev.value_counts()
# Out:
# inulin + H2O                            12
# 4-nitrophenyl beta-D-glucopyranoside     9
# filaggrin-L-arginine + H2O               6
# ADP + D-glucose                          4
# xylan                                    4
#                                         ..
# benzaldehyde                             1
# L-lactate + NAD+                         1
# oxaloacetate + NADH + H+                 1
# (S)-malate + NAD+                        1
# D-xylulose + NADH + H+                   1
# Name: substrates_rev, Length: 98, dtype: int64

# %%
data_redox.substrates_rev.value_counts()
# Out:
# (+)-bornane-2,5-dione + FMNH2 + O2                        4
# cellobiose                                                4
# glutathione + dehydroascorbate                            3
# pyruvate + NADH + H+                                      2
# spermine                                                  2
# reduced coenzyme F420 + NADP+                             2
# pyruvate + NH3 + NADH                                     2
# propanal                                                  2
# methylmalonate-semialdehyde + CoA + NAD+                  2
# 2-acetolactate                                            2
# glyoxylate                                                2
# 6-phospho-D-gluconate + NADP+                             2
# (S)-malate + NADP+                                        2
# 2-pentanone                                               2
# salutaridine + NADPH + H+                                 2
# (7S)-salutaridinol + NADP+', 'salutaridinol + NADP+       2
# scytalone + NADP+                                         1
# propane-1,3-diol + NAD+                                   1
# sorbitol + NAD+                                           1
# D-fructose + NADH + H+                                    1
# feruloyl-CoA + NADPH + H+                                 1
# uracil + NADPH                                            1
# D-arabitol                                                1
# L-alanine + NAD+ + H2O                                    1
# 2-oxo-4-methylselenobutyrate + NH3 + NADH                 1
# L-phenylalanine                                           1
# L-alanine                                                 1
# putrescine + H2O + O2                                     1
# taurine + NADH + H+ + pyruvate                            1
# tauropine + NAD+ + H2O                                    1
# D-xylulose                                                1
# DELTA1-pyrroline-2-carboxylate + NADH + H+                1
# L-proline + NAD+                                          1
# benzyl alcohol                                            1
# norspermine                                               1
# thermospermine                                            1
# D-proline                                                 1
# L-aspartate 4-semialdehyde + phosphate + NADP+            1
# 2,6-dimethoxyphenol                                       1
# S)-lactate + NAD+                                         1
# D-ribulose                                                1
# L-lactate + NAD+                                          1
# oxaloacetate + NADH + H+                                  1
# (S)-malate + NAD+                                         1
# acetoin                                                   1
# pyruvate + CO2 + NADPH                                    1
# 1,3,6,8-tetrahydroxynaphthalene + NADPH + H+              1
# pyruvate + CO2 + NADPH + H+                               1
# D-fructose + NADPH + H+                                   1
# dihydroxyacetone                                          1
# 2,2'-azino-bis(3-ethylbenzothiazoline-6-sulfonic acid)    1
# glycerol                                                  1
# dihydroxyacetone phosphate + NADH + H+                    1
# benzaldehyde                                              1
# xylitol + NAD+                                            1
# dihydroxyfumarate + NADH                                  1
# mesotartrate + NAD+                                       1
# D-glucose + FAD                                           1
# 3-hydroxypropanal + NADH + H+                             1
# D-xylulose + NADH + H+                                    1
# Name: substrates_rev, dtype: int64
