# %%
import numpy as np
import pandas as pd
import os
from Bio import SeqIO
import itertools
from typing import List, Tuple
import string
from pathlib import Path
from tqdm.auto import tqdm, trange

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
os.chdir("../../../")
os.getcwd()
# Out:
# '/lustre/eaglefs/projects/robustmicrob/jlaw/projects/prot_stability_engineering'

# %% [markdown]
# ### Load and combine the ph range and ph opt datasets
# 1. Brenda ph range
# 2. E coli manual parsing
# 3. Brenda ph opt

# %%
def check_ph_act(df):
    """ check to make sure the ph and activity values are within the expected range
    """
    out_of_range = df[(df.ph > 13) | (df.ph < 1) | (df.activity > 1) | (df.activity < 0)]
    print(f"{len(out_of_range) = }")
    if len(out_of_range) > 0:
        print(out_of_range)

# %%
inputs_dir = "inputs/brenda"

# %%
# load the pH range and opt values
data_file = Path(inputs_dir, "ph_range/20230907_ph_range_wrxn_type.csv")
print(data_file)
data = pd.read_csv(data_file, index_col=0)
print(len(data))

act_file = Path(inputs_dir, "ph_range/20230907_ph_range_processed_act_wopt.csv")
print(act_file)
data_act = pd.read_csv(act_file)
print(len(data_act))
data_act = data_act[data_act.exp_index.isin(data.index)]
data_act['uniprot_id'] = data_act.exp_index.apply(lambda x: data.loc[x].uniprot_id)
print(len(data_act))
data_act.head(2)
# Out:
# inputs/brenda/ph_range/20230907_ph_range_wrxn_type.csv
# 3158
# inputs/brenda/ph_range/20230907_ph_range_processed_act_wopt.csv
# 9440
# 9383
#    exp_index   ph  activity note  \
# 0          1  4.0       0.8  NaN
# 1          1  7.5       0.6  NaN
#
#                                     ph_range_comment uniprot_id
# 0  pH 4.0: about 80% of maximal activity, pH 7.5:...     B2KJ46
# 1  pH 4.0: about 80% of maximal activity, pH 7.5:...     B2KJ46

# %%
check_ph_act(data_act)
# Out:
# len(out_of_range) = 2
#       exp_index   ph  activity                                   note  \
# 7212       4912  6.0       5.0  at pH 4.is about 2% of that at pH 7.4
# 7214       4912  9.0       5.0  at pH 4.is about 2% of that at pH 7.4
#
#                                        ph_range_comment uniprot_id
# 7212  at pH 4.5 the activity is about 2% of that at ...     P00571
# 7214  at pH 4.5 the activity is about 2% of that at ...     P00571

# %%
# drop this exp. Looks like it was parsed wrong
data = data[data.index != 4912]
data_act = data_act[data_act.exp_index != 4912]

# %%
check_ph_act(data_act)
# Out:
# len(out_of_range) = 0

# %%
data_act.uniprot_id.value_counts()
# Out:
# Q6LXQ3    34
# B0L0Y4    24
# A1YLF2    24
# A1YLF1    24
# Q5LS57    24
#           ..
# Q0V8L2     1
# A7YWM1     1
# Q60136     1
# Q9RKU9     1
# Q8U0A9     1
# Name: uniprot_id, Length: 2566, dtype: int64

# %%
# also load the manual E coli dataset
data_file = Path(inputs_dir, "ph_range/ecoli/20230712_ph_curve_data_redox_ann.csv")
print(data_file)
data_ecoli = pd.read_csv(data_file, index_col=0)
print(len(data_ecoli))

act_file = Path(inputs_dir, "ph_range/ecoli/20230712_ph_curve_data_processed_activities.csv")
print(act_file)
data_act_ecoli = pd.read_csv(act_file)
data_act_ecoli['uniprot_id'] = data_act_ecoli.exp_index.apply(lambda x: data_ecoli.loc[x].uniprot_id)
print(len(data_act_ecoli))
data_act_ecoli.head(2)
# Out:
# inputs/brenda/ph_range/ecoli/20230712_ph_curve_data_redox_ann.csv
# 282
# inputs/brenda/ph_range/ecoli/20230712_ph_curve_data_processed_activities.csv
# 3165
#    exp_index   pH  activity uniprot_id
# 0          0  7.2  0.012428     P21515
# 1          0  7.5  0.090313     P21515

# %%
data_act_ecoli.uniprot_id.value_counts()
# Out:
# P25524    96
# P19926    84
# P06721    70
# P00864    53
# P10902    53
#           ..
# P17444     5
# P37197     5
# P0A9T0     4
# P0A725     3
# P45568     2
# Name: uniprot_id, Length: 195, dtype: int64

# %%
# load the pHopt values
data_opt = pd.read_csv("inputs/brenda/ph_opt/20230907_ph_opt_no_ph_range_ez_type.csv", index_col=0)
print(data_opt.uniprot_id.nunique(), len(data_opt))
data_opt.head(2)
# Out:
# 7660 10683
#         ec_num                              name  ph_min ph_max comments  \
# 4701  2.1.1.10  homocysteine S-methyltransferase     7.2      -        -
# 4702  2.1.1.10  homocysteine S-methyltransferase     7.5      -        -
#
#                   organism uniprot_id     ref  ph_range_ref_match  \
# 4701     Brassica oleracea     A4ZGQ8  676384                 NaN
# 4702  Arabidopsis thaliana     Q9M1W4  441387                 NaN
#
#      reaction_type note cofactor substrate   enzyme_type   enzyme_type_sub   \
# 4701           NaN  NaN      NaN       NaN  Transferases  one-carbon groups
# 4702           NaN  NaN      NaN       NaN  Transferases  one-carbon groups
#
#      acceptor
# 4701      NaN
# 4702      NaN

# %%
# combine the ph_min and ph_max columns 
data_opt_ph_max = data_opt[data_opt.ph_max != "-"]
data_opt_ph_max = data_opt_ph_max.rename(columns={"ph_max": "ph_opt"}).drop(columns="ph_min")
data_opt_ph_min = data_opt.rename(columns={"ph_min": "ph_opt"}).drop(columns="ph_max")
data_opt_2 = pd.concat([data_opt_ph_min, data_opt_ph_max])
data_opt_2 = data_opt_2.sort_values(["ec_num", "organism"])
data_opt_2.head(2)
# Out:
#         ec_num                   name ph_opt                        comments  \
# 18216  1.1.1.1  alcohol dehydrogenase    8.0  and a second optimum at pH 9.5
# 18220  1.1.1.1  alcohol dehydrogenase    9.5  and a second optimum at pH 8.0
#
#                       organism uniprot_id     ref  ph_range_ref_match  \
# 18216  Drosophila melanogaster     P00334  285619                 NaN
# 18220  Drosophila melanogaster     P00334  285619                 NaN
#
#       reaction_type note cofactor substrate      enzyme_type  \
# 18216           NaN  NaN      NaN       NaN  Oxidoreductases
# 18220           NaN  NaN      NaN       NaN  Oxidoreductases
#
#             enzyme_type_sub        acceptor
# 18216  CH-OH group of donors  NAD+ or NADP+
# 18220  CH-OH group of donors  NAD+ or NADP+

# %%
data_opt_2.uniprot_id.value_counts()
# Out:
# P08659        17
# C4TJD2        14
# Q5M886        13
# Q9NR71        13
# Q9Z1M7        12
#               ..
# A0A286JZ72     1
# Q8U1H4         1
# B5L0W0         1
# K7ZLW6         1
# Q0PCR9         1
# Name: uniprot_id, Length: 7660, dtype: int64

# %%
data_opt_2[data_opt_2.uniprot_id.isin(data_opt_2.uniprot_id.value_counts().head(2).index)]
# Out:
#           ec_num                                 name ph_opt  \
# 2267   1.13.12.7                   firefly luciferase    5.0
# 2268   1.13.12.7                   firefly luciferase    5.4
# 2269   1.13.12.7                   firefly luciferase    5.5
# 2271   1.13.12.7                   firefly luciferase    7.5
# 2273   1.13.12.7                   firefly luciferase    7.5
# 2274   1.13.12.7                   firefly luciferase    7.6
# 2277   1.13.12.7                   firefly luciferase    7.8
# 2278   1.13.12.7                   firefly luciferase    7.8
# 2279   1.13.12.7                   firefly luciferase    7.8
# 2280   1.13.12.7                   firefly luciferase    7.8
# 2281   1.13.12.7                   firefly luciferase    7.8
# 2292   1.13.12.7                   firefly luciferase    8.0
# 2295   1.13.12.7                   firefly luciferase    8.1
# 2299   1.13.12.7                   firefly luciferase    9.0
# 2267   1.13.12.7                   firefly luciferase      6
# 2271   1.13.12.7                   firefly luciferase    7.8
# 2273   1.13.12.7                   firefly luciferase      8
# 16005   4.2.2.11   guluronate-specific alginate lyase    7.6
# 16005   4.2.2.11   guluronate-specific alginate lyase      9
# 16152    4.2.2.3  mannuronate-specific alginate lyase    7.6
# 16153    4.2.2.3  mannuronate-specific alginate lyase    7.6
# 16156    4.2.2.3  mannuronate-specific alginate lyase    7.6
# 16157    4.2.2.3  mannuronate-specific alginate lyase    7.6
# 16164    4.2.2.3  mannuronate-specific alginate lyase    8.0
# 16165    4.2.2.3  mannuronate-specific alginate lyase    8.0
# 16152    4.2.2.3  mannuronate-specific alginate lyase      9
# 16153    4.2.2.3  mannuronate-specific alginate lyase      9
# 16156    4.2.2.3  mannuronate-specific alginate lyase      9
# 16157    4.2.2.3  mannuronate-specific alginate lyase      9
# 16164    4.2.2.3  mannuronate-specific alginate lyase      9
# 16165    4.2.2.3  mannuronate-specific alginate lyase      9
#
#                                                 comments          organism  \
# 2267                                   red emitted light  Photinus pyralis
# 2268                                   red emitted light  Photinus pyralis
# 2269             shift of emission spectra to red region  Photinus pyralis
# 2271                          yellow-green emitted light  Photinus pyralis
# 2273                      pH 7.8, 25°C, wild-type enzyme  Photinus pyralis
# 2274                          yellow-green emitted light  Photinus pyralis
# 2277                                                   -  Photinus pyralis
# 2278                                                   -  Photinus pyralis
# 2279                                                   -  Photinus pyralis
# 2280                                                   -  Photinus pyralis
# 2281                                                   -  Photinus pyralis
# 2292                                    wild-type enzyme  Photinus pyralis
# 2295                                                   -  Photinus pyralis
# 2299                         recombinant circular enzyme  Photinus pyralis
# 2267                                   red emitted light  Photinus pyralis
# 2271                          yellow-green emitted light  Photinus pyralis
# 2273                      pH 7.8, 25°C, wild-type enzyme  Photinus pyralis
# 16005                                                  -        Vibrio sp.
# 16005                                                  -        Vibrio sp.
# 16152                                                  -        Vibrio sp.
# 16153                                                  -        Vibrio sp.
# 16156  recombinant isoform A9mT, in 100 mM Tris-HCl b...        Vibrio sp.
# 16157  recombinant isoform A9mT, in 100 mM Tris-HCl b...        Vibrio sp.
# 16164                     crude recombinant A9mL isozyme        Vibrio sp.
# 16165                     crude recombinant A9mL isozyme        Vibrio sp.
# 16152                                                  -        Vibrio sp.
# 16153                                                  -        Vibrio sp.
# 16156  recombinant isoform A9mT, in 100 mM Tris-HCl b...        Vibrio sp.
# 16157  recombinant isoform A9mT, in 100 mM Tris-HCl b...        Vibrio sp.
# 16164                     crude recombinant A9mL isozyme        Vibrio sp.
# 16165                     crude recombinant A9mL isozyme        Vibrio sp.
#
#       uniprot_id                                                ref  \
# 2267      P08659                                             698393
# 2268      P08659                                             697221
# 2269      P08659                                             696341
# 2271      P08659                                             698393
# 2273      P08659                                             764596
# 2274      P08659                                             697221
# 2277      P08659  484842, 484843, 671869, 672684, 686447, 696341...
# 2278      P08659  484842, 484843, 671869, 672684, 686447, 696341...
# 2279      P08659  484842, 484843, 671869, 672684, 686447, 696341...
# 2280      P08659  484842, 484843, 671869, 672684, 686447, 696341...
# 2281      P08659  484842, 484843, 671869, 672684, 686447, 696341...
# 2292      P08659                                             746213
# 2295      P08659                                             484861
# 2299      P08659                                             746213
# 2267      P08659                                             698393
# 2271      P08659                                             698393
# 2273      P08659                                             764596
# 16005     C4TJD2                                             705481
# 16005     C4TJD2                                             705481
# 16152     C4TJD2                                             705481
# 16153     C4TJD2                                             705481
# 16156     C4TJD2                                             705481
# 16157     C4TJD2                                             705481
# 16164     C4TJD2                                             705481
# 16165     C4TJD2                                             705481
# 16152     C4TJD2                                             705481
# 16153     C4TJD2                                             705481
# 16156     C4TJD2                                             705481
# 16157     C4TJD2                                             705481
# 16164     C4TJD2                                             705481
# 16165     C4TJD2                                             705481
#
#        ph_range_ref_match reaction_type note cofactor substrate  \
# 2267                  NaN           NaN  NaN      NaN       NaN
# 2268                  NaN           NaN  NaN      NaN       NaN
# 2269                  NaN           NaN  NaN      NaN       NaN
# 2271                  NaN           NaN  NaN      NaN       NaN
# 2273                  NaN           NaN  NaN      NaN       NaN
# 2274                  NaN           NaN  NaN      NaN       NaN
# 2277                  NaN           NaN  NaN      NaN       NaN
# 2278                  NaN           NaN  NaN      NaN       NaN
# 2279                  NaN           NaN  NaN      NaN       NaN
# 2280                  NaN           NaN  NaN      NaN       NaN
# 2281                  NaN           NaN  NaN      NaN       NaN
# 2292                  NaN           NaN  NaN      NaN       NaN
# 2295                  NaN           NaN  NaN      NaN       NaN
# 2299                  NaN           NaN  NaN      NaN       NaN
# 2267                  NaN           NaN  NaN      NaN       NaN
# 2271                  NaN           NaN  NaN      NaN       NaN
# 2273                  NaN           NaN  NaN      NaN       NaN
# 16005                 NaN           NaN  NaN      NaN       NaN
# 16005                 NaN           NaN  NaN      NaN       NaN
# 16152                 NaN           NaN  NaN      NaN       NaN
# 16153                 NaN           NaN  NaN      NaN       NaN
# 16156                 NaN           NaN  NaN      NaN       NaN
# 16157                 NaN           NaN  NaN      NaN       NaN
# 16164                 NaN           NaN  NaN      NaN       NaN
# 16165                 NaN           NaN  NaN      NaN       NaN
# 16152                 NaN           NaN  NaN      NaN       NaN
# 16153                 NaN           NaN  NaN      NaN       NaN
# 16156                 NaN           NaN  NaN      NaN       NaN
# 16157                 NaN           NaN  NaN      NaN       NaN
# 16164                 NaN           NaN  NaN      NaN       NaN
# 16165                 NaN           NaN  NaN      NaN       NaN
#
#            enzyme_type enzyme_type_sub  acceptor
# 2267   Oxidoreductases       oxygenases    other
# 2268   Oxidoreductases       oxygenases    other
# 2269   Oxidoreductases       oxygenases    other
# 2271   Oxidoreductases       oxygenases    other
# 2273   Oxidoreductases       oxygenases    other
# 2274   Oxidoreductases       oxygenases    other
# 2277   Oxidoreductases       oxygenases    other
# 2278   Oxidoreductases       oxygenases    other
# 2279   Oxidoreductases       oxygenases    other
# 2280   Oxidoreductases       oxygenases    other
# 2281   Oxidoreductases       oxygenases    other
# 2292   Oxidoreductases       oxygenases    other
# 2295   Oxidoreductases       oxygenases    other
# 2299   Oxidoreductases       oxygenases    other
# 2267   Oxidoreductases       oxygenases    other
# 2271   Oxidoreductases       oxygenases    other
# 2273   Oxidoreductases       oxygenases    other
# 16005           Lyases    Carbon-oxygen      NaN
# 16005           Lyases    Carbon-oxygen      NaN
# 16152           Lyases    Carbon-oxygen      NaN
# 16153           Lyases    Carbon-oxygen      NaN
# 16156           Lyases    Carbon-oxygen      NaN
# 16157           Lyases    Carbon-oxygen      NaN
# 16164           Lyases    Carbon-oxygen      NaN
# 16165           Lyases    Carbon-oxygen      NaN
# 16152           Lyases    Carbon-oxygen      NaN
# 16153           Lyases    Carbon-oxygen      NaN
# 16156           Lyases    Carbon-oxygen      NaN
# 16157           Lyases    Carbon-oxygen      NaN
# 16164           Lyases    Carbon-oxygen      NaN
# 16165           Lyases    Carbon-oxygen      NaN

# %%
data_opt_2["ph_opt"] = data_opt_2.ph_opt.astype(float)
data_opt_2["ph_opt"].value_counts()
# Out:
# 8.00     1701
# 7.00     1467
# 7.50     1362
# 6.00     1003
# 8.50      813
#          ...
# 9.75        1
# 1.00        1
# 11.30       1
# 1.30        1
# 7.31        1
# Name: ph_opt, Length: 114, dtype: int64

# %%
df
# Out:
#          ec_num                     name  ph_opt comments  \
# 4672  1.8.99.B2  tetrathionate reductase     2.5        -
#
#                             organism uniprot_id     ref  ph_range_ref_match  \
# 4672  Acidithiobacillus ferrooxidans     B7J3E3  741675                 NaN
#
#      reaction_type note cofactor substrate      enzyme_type  \
# 4672     reduction  NaN      NaN       NaN  Oxidoreductases
#
#             enzyme_type_sub  acceptor
# 4672  sulfur group of donors    other

# %%
# for each uniprot ID and redox_type combo, take the average pH as the optimum
data_opt_mean = []
for cols, df in data_opt_2.groupby(["ec_num", "uniprot_id", "reaction_type"], dropna=False):
    # print(cols, df)
    if len(df) == 1:
        data_opt_mean += [df]
        continue
    ph_min, ph_max = df.ph_opt.min(), df.ph_opt.max()
    df["max_min_diff"] = ph_max - ph_min
    # remove proteins with a ph opt spread > 4 ph
    if abs(ph_max - ph_min) > 4:
        # print(df)
        continue
    ph_mean = df.ph_opt.mean()
    df["ph_opt"] = ph_mean
    data_opt_mean += [df.head(1)]

data_opt_mean = pd.concat(data_opt_mean)
print(len(data_opt_2), len(data_opt_mean))
data_opt_mean.head(2)
# Out:
# 13014 8136
#      ec_num                   name  ph_opt  \
# 59  1.1.1.1  alcohol dehydrogenase    10.0
# 15  1.1.1.1  alcohol dehydrogenase     6.0
#
#                                              comments  \
# 59  glycine–NaOH buffer, highest activity for oxid...
# 15  sodium phosphate buffer, highest activity for ...
#
#                     organism uniprot_id     ref  ph_range_ref_match  \
# 59  Pyrobaculum calidifontis     A3MVR8  742472                 NaN
# 15  Pyrobaculum calidifontis     A3MVR8  742472                 NaN
#
#    reaction_type note cofactor substrate      enzyme_type  \
# 59     oxidation  NaN      NaN       NaN  Oxidoreductases
# 15     reduction  NaN      NaN       NaN  Oxidoreductases
#
#          enzyme_type_sub        acceptor  max_min_diff
# 59  CH-OH group of donors  NAD+ or NADP+           NaN
# 15  CH-OH group of donors  NAD+ or NADP+           NaN

# %%
data_opt_mean.max_min_diff.plot.hist(bins=30)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# we already matched the ph_opt data to the ph_range, so just keep the unique uniprot IDs here
data_opt_mean_uniq = data_opt_mean[~data_opt_mean.index.isin(data_act.uniprot_id.unique())]
data_opt_mean_uniq = data_opt_mean_uniq.reset_index()
data_opt_mean_uniq = data_opt_mean_uniq.rename(columns={'ph_opt': 'ph'})
data_opt_mean_uniq['activity'] = 1
print(len(data_opt_mean), len(data_opt_mean_uniq))
data_opt_mean_uniq.head(2)
# Out:
# 8136 8136
#    index   ec_num                   name    ph  \
# 0     59  1.1.1.1  alcohol dehydrogenase  10.0
# 1     15  1.1.1.1  alcohol dehydrogenase   6.0
#
#                                             comments  \
# 0  glycine–NaOH buffer, highest activity for oxid...
# 1  sodium phosphate buffer, highest activity for ...
#
#                    organism uniprot_id     ref  ph_range_ref_match  \
# 0  Pyrobaculum calidifontis     A3MVR8  742472                 NaN
# 1  Pyrobaculum calidifontis     A3MVR8  742472                 NaN
#
#   reaction_type note cofactor substrate      enzyme_type  \
# 0     oxidation  NaN      NaN       NaN  Oxidoreductases
# 1     reduction  NaN      NaN       NaN  Oxidoreductases
#
#         enzyme_type_sub        acceptor  max_min_diff  activity
# 0  CH-OH group of donors  NAD+ or NADP+           NaN         1
# 1  CH-OH group of donors  NAD+ or NADP+           NaN         1

# %%
check_ph_act(data_opt_mean_uniq)
# Out:
# len(out_of_range) = 0

# %%
data_act_ecoli['note'] = 'ecoli_man'
data_act_ecoli.rename(columns={'pH': 'ph'}, inplace=True)
# Fix the activities just below 0
data_act_ecoli.loc[data_act_ecoli.activity < 0, 'activity'] = 0

# %%
check_ph_act(data_act_ecoli)
# Out:
# len(out_of_range) = 14
#       exp_index    ph  activity uniprot_id       note
# 75           16   9.1  1.005900     P21514  ecoli_man
# 196          37  10.0  1.001300     P0A6C5  ecoli_man
# 197          37  10.5  1.004000     P0A6C5  ecoli_man
# 205          38   7.0  1.050000     P0A6C5  ecoli_man
# 335          48   8.0  1.001639     P0AC88  ecoli_man
# 359          50   7.9  1.001270     P09126  ecoli_man
# 525          66   7.5  1.001060     P27306  ecoli_man
# 545          68   5.3  1.002049     P07658  ecoli_man
# 546          68   5.8  1.016393     P07658  ecoli_man
# 547          68   6.2  1.057377     P07658  ecoli_man
# 1180        133   4.5  1.002179     P19926  ecoli_man
# 1207        134   6.5  1.002179     P19926  ecoli_man
# 1223        135   3.5  1.002179     P19926  ecoli_man
# 1783        230  13.5  0.002390     P21179  ecoli_man

# %%
data_act_ecoli.head(2)
# Out:
#    exp_index   ph  activity uniprot_id       note
# 0          0  7.2  0.012428     P21515  ecoli_man
# 1          0  7.5  0.090313     P21515  ecoli_man

# %%
data_ecoli.head(2)
# Out:
#            gene uniprot_id b_number data_type mutation  \
# exp_index
# 0          acpH     P21515    b0404        ph      NaN
# 3          speA     P21170    b2938        ph       wt
#
#                                      doi figure_id time condition  \
# exp_index
# 0          10.1016/S0021-9258(18)96069-2      fig4   30        33
# 3          10.1016/j.molcatb.2015.06.008       NaN   15         4
#
#           reaction_note curator redox_type
# exp_index
# 0                   NaN      JL        NaN
# 3                   NaN      JL        NaN

# %%
data_act_ecoli["reaction_type"] = data_act_ecoli.exp_index.apply(
    lambda x: data_ecoli.loc[x].redox_type)
data_act_ecoli.head(2)
# Out:
#    exp_index   ph  activity uniprot_id       note reaction_type
# 0          0  7.2  0.012428     P21515  ecoli_man           NaN
# 1          0  7.5  0.090313     P21515  ecoli_man           NaN

# %%
data_act.head(2)
# Out:
#    exp_index   ph  activity note  \
# 0          1  4.0       0.8  NaN
# 1          1  7.5       0.6  NaN
#
#                                     ph_range_comment uniprot_id
# 0  pH 4.0: about 80% of maximal activity, pH 7.5:...     B2KJ46
# 1  pH 4.0: about 80% of maximal activity, pH 7.5:...     B2KJ46

# %%
# add the enzyme type columns
ez_cols = ["redox_type", "enzyme_type", "enzyme_type_sub", "acceptor"]
data_act[ez_cols] = data_act.exp_index.apply(
    lambda x: data.loc[x][ez_cols])
data_act = data_act.drop(columns="reaction_type").rename(columns={"redox_type": "reaction_type"})
data_act.head(2)
# Out:
#    exp_index   ph  activity note  \
# 0          1  4.0       0.8  NaN
# 1          1  7.5       0.6  NaN
#
#                                     ph_range_comment uniprot_id reaction_type  \
# 0  pH 4.0: about 80% of maximal activity, pH 7.5:...     B2KJ46     reduction
# 1  pH 4.0: about 80% of maximal activity, pH 7.5:...     B2KJ46     reduction
#
#        enzyme_type        enzyme_type_sub       acceptor redox_type
# 0  Oxidoreductases  CH-OH group of donors  NAD+ or NADP+  reduction
# 1  Oxidoreductases  CH-OH group of donors  NAD+ or NADP+  reduction

# %%
print(len(data_act), len(data_act_ecoli), len(data_opt_mean_uniq))
print(data_act.uniprot_id.nunique(), data_act_ecoli.uniprot_id.nunique(), data_opt_mean_uniq.uniprot_id.nunique())
# Out:
# 9380 3165 8136
# 2566 195 7622

# %%
data_act_merged = pd.concat([data_act, data_act_ecoli, data_opt_mean_uniq], ignore_index=True).reset_index(drop=True)
print(data_act_merged.uniprot_id.nunique(), len(data_act_merged))
data_act_merged.head(2)
# Out:
# 10326 20681
#    exp_index   ph  activity note  \
# 0        1.0  4.0       0.8  NaN
# 1        1.0  7.5       0.6  NaN
#
#                                     ph_range_comment uniprot_id  \
# 0  pH 4.0: about 80% of maximal activity, pH 7.5:...     B2KJ46
# 1  pH 4.0: about 80% of maximal activity, pH 7.5:...     B2KJ46
#
#        enzyme_type        enzyme_type_sub       acceptor reaction_type  ...  \
# 0  Oxidoreductases  CH-OH group of donors  NAD+ or NADP+     reduction  ...
# 1  Oxidoreductases  CH-OH group of donors  NAD+ or NADP+     reduction  ...
#
#    ec_num name comments organism  ref ph_range_ref_match  cofactor substrate  \
# 0     NaN  NaN      NaN      NaN  NaN                NaN       NaN       NaN
# 1     NaN  NaN      NaN      NaN  NaN                NaN       NaN       NaN
#
#   enzyme_type_sub  max_min_diff
# 0              NaN          NaN
# 1              NaN          NaN
#
# [2 rows x 21 columns]

# %%
out_file = Path(inputs_dir, "20230922_ph_data_merged.csv")
data_act_merged.to_csv(out_file, index=False)

# %% [markdown]
# ### Leave off the ph_opt data for now as it might be throwing off the predictor for standard deviation
# - The highest possible std dev is always being predicted

# %%
data_act_merged = pd.concat([data_act, data_act_ecoli], ignore_index=True).reset_index(drop=True)
print(data_act_merged.uniprot_id.nunique(), len(data_act_merged))
data_act_merged.head(2)
# Out:
# 2301 9506
#    exp_index   ph  activity note  \
# 0          0  4.0       0.8  NaN
# 1          0  4.5       1.0  NaN
#
#                                     ph_range_comment uniprot_id
# 0   pH 4.0: about 80% of maximal activity, pH 7.5...     B2KJ46
# 1                                                NaN     B2KJ46

# %%
out_file = Path(inputs_dir, "20230726_ph_range_data_merged.csv")
data_act_merged.to_csv(out_file, index=False)
