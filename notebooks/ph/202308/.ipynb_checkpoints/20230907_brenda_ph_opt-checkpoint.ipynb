# %% [markdown]
# ## BRENDA pH activity data
# - BRENDA has "pH optimum" and "pH range" fields
# - We need to match up the data from these two sheets
# - This notebook will parse the "pH optimum" data and match it with the ph range data

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import os
import re
import regex
from tqdm.auto import tqdm

# %%
inputs_dir = Path("/projects/robustmicrob/jlaw/inputs/brenda/202301_tables")
data_dir = "/projects/robustmicrob/jlaw/projects/prot_stability_engineering/inputs/brenda"

# %%
ph_range_file = inputs_dir / "202301_ph_opt.tsv.gz"
header = ["ec_num", "name", "ph_min", "ph_max", "comments", "organism", "uniprot_id", "ref", "empty"]
data = pd.read_csv(ph_range_file, sep='\t', names=header)
data = data.drop(columns=['empty'])
print(len(data))
data = data[data.ph_min != "additional information"]
# data = data[data.ph_min != "additional information"]
print(len(data))
data.head(2)
# Out:
# 51028
# 50084
#     ec_num                   name ph_min ph_max                comments  \
# 2  1.1.1.1  alcohol dehydrogenase      3      -  reduction of aldehydes
# 3  1.1.1.1  alcohol dehydrogenase    3.8      -                    -4.3
#
#                     organism uniprot_id     ref
# 2  Thermococcus kodakarensis     Q5JI09  735486
# 3          Neurospora crassa          -  659773

# %%
data.organism.value_counts()
# Out:
# Homo sapiens                    3979
# Rattus norvegicus               2213
# Escherichia coli                1885
# Bos taurus                      1029
# Saccharomyces cerevisiae        1013
#                                 ...
# Palaemon serratus                  1
# Parophrys vetulus                  1
# Pleuronichthys verticalis          1
# Pseudopleuronectes yokohamae       1
# Acyrthosiphon pisum                1
# Name: organism, Length: 5906, dtype: int64

# %% [markdown]
# #### Find a uniprot ID for rows where it's missing
# See if we can use the mapping from the uniprot ID's ec numbers to get a protein

# %%
uniprot_ec_file = f"{data_dir}/uniprot/uniprotkb_ec_AND_reviewed_true_2023_07_06.tsv.gz"
uniprot_ec_df = pd.read_table(uniprot_ec_file)
print(len(uniprot_ec_df))
uniprot_ec_df.head(2)
# Out:
# 274744
#         Entry  Reviewed   Entry Name  \
# 0  A0A009IHW8  reviewed  ABTIR_ACIB9
# 1  A0A023I7E1  reviewed   ENG1_RHIMI
#
#                                        Protein names   Gene Names  \
# 0  2' cyclic ADP-D-ribose synthase AbTIR (2'cADPR...    J512_3302
# 1  Glucan endo-1,3-beta-D-glucosidase 1 (Endo-1,3...  ENG1 LAM81A
#
#                                    Organism  Length         EC number
# 0  Acinetobacter baumannii (strain 1295743)     269  3.2.2.-; 3.2.2.6
# 1                         Rhizomucor miehei     796          3.2.1.39

# %%
data_no_uniprot = data[data.uniprot_id == "-"]
len(data_no_uniprot)
# Out:
# 36326

# %%
data_matched_uniprot = pd.DataFrame()
for ec_num, df in tqdm(data_no_uniprot.groupby('ec_num')):
    uniprot_ec_rows = uniprot_ec_df[uniprot_ec_df['EC number'].apply(lambda x: ec_num in x.split('; '))]
    if len(uniprot_ec_rows) == 0:
        continue

    org_count = df.organism.value_counts().to_dict()
    
    def match_uniprot_ec_organism(org, 
                                  num_brenda_org_cutoff=2,
                                  num_matching_rows_cutoff=2):
        # only try and automatically match for brenda entries that have fewer than 3 entries for the same enzyme
        if org_count[org] > num_brenda_org_cutoff:
            return np.nan

        matching_rows = uniprot_ec_rows[uniprot_ec_rows.Organism.apply(lambda x: org in x)]
        if len(matching_rows) > num_matching_rows_cutoff:
            return np.nan

        return ",".join(matching_rows.Entry.values)

    df['uniprot_id'] = df.organism.apply(match_uniprot_ec_organism)
    data_matched_uniprot = pd.concat([data_matched_uniprot, df])

print(len(data_matched_uniprot))
# Out:
#   0%|          | 0/4539 [00:00<?, ?it/s]
# 33505

# %%
data_matched_uniprot.uniprot_id = data_matched_uniprot.uniprot_id.replace("",np.nan)
data_matched_uniprot = data_matched_uniprot.dropna(subset='uniprot_id')

# %%
print(len(data_matched_uniprot), data_matched_uniprot.uniprot_id.nunique())
# Out:
# 5469 4268

# %%
data_uniprot = data[data.uniprot_id != '-'].dropna(subset='uniprot_id')
print(len(data_uniprot), data_uniprot.uniprot_id.nunique())
data_uniprot = pd.concat([data_uniprot, data_matched_uniprot])
print(len(data_uniprot), data_uniprot.uniprot_id.nunique())
data_uniprot = data_uniprot.drop_duplicates()
print(len(data_uniprot), data_uniprot.uniprot_id.nunique())
# Out:
# 13756 10465
# 19225 14208
# 19225 14208

# %%
data_uniprot.uniprot_id.value_counts()
# Out:
# Q51723           17
# P08659           14
# P00784           13
# Q9AJE3           11
# O23791           11
#                  ..
# Q5AVY9            1
# Q9KIF2            1
# B3VS85            1
# C7A621            1
# P97046,Q9CHL8     1
# Name: uniprot_id, Length: 14208, dtype: int64

# %%
# split rows with multiple uniprot IDs
data_uniprot["uniprot_id"] = data_uniprot.uniprot_id.apply(lambda x: x.replace(' AND ',',').replace(' ','').split(','))
data_uniprot = data_uniprot.explode(column='uniprot_id', ignore_index=True)
print(len(data_uniprot), data_uniprot.uniprot_id.nunique())
# Out:
# 24674 15793

# %%
data_uniprot.uniprot_id.value_counts()
# Out:
# P27169    34
# Q975F9    33
# Q51723    20
# P08659    19
# Q9NR71    19
#           ..
# Q2QC90     1
# Q6HA27     1
# P48147     1
# W8GKU3     1
# Q9CHL8     1
# Name: uniprot_id, Length: 15793, dtype: int64

# %%
data_uniprot[data_uniprot.uniprot_id == "P27169"]
# Out:
#          ec_num                                          name ph_min ph_max  \
# 9203    3.1.1.2                                  arylesterase    7.4      -
# 9204    3.1.1.2                                  arylesterase    7.4      -
# 9208    3.1.1.2                                  arylesterase      8      -
# 9209    3.1.1.2                                  arylesterase      8      -
# 9210    3.1.1.2                                  arylesterase      8      -
# 9213    3.1.1.2                                  arylesterase      8      -
# 9214    3.1.1.2                                  arylesterase      8      -
# 9215    3.1.1.2                                  arylesterase      8      -
# 9216    3.1.1.2                                  arylesterase      8      -
# 9221    3.1.1.2                                  arylesterase    8.5      -
# 9222    3.1.1.2                                  arylesterase    8.5      -
# 9272   3.1.1.25                                 1,4-lactonase      8      -
# 9669   3.1.1.81  quorum-quenching N-acyl-homoserine lactonase      8      -
# 10451   3.1.8.1                        aryldialkylphosphatase    7.4      -
# 10452   3.1.8.1                        aryldialkylphosphatase    7.4      -
# 10454   3.1.8.1                        aryldialkylphosphatase    7.5      8
# 10457   3.1.8.1                        aryldialkylphosphatase      8      -
# 10461   3.1.8.1                        aryldialkylphosphatase      8      -
# 10462   3.1.8.1                        aryldialkylphosphatase      8      -
# 10463   3.1.8.1                        aryldialkylphosphatase      8      -
# 10464   3.1.8.1                        aryldialkylphosphatase      8      -
# 10465   3.1.8.1                        aryldialkylphosphatase      8      -
# 10466   3.1.8.1                        aryldialkylphosphatase      8      -
# 10467   3.1.8.1                        aryldialkylphosphatase      8      -
# 10478   3.1.8.1                        aryldialkylphosphatase    8.5      -
# 10480   3.1.8.1                        aryldialkylphosphatase    8.5      -
# 10481   3.1.8.1                        aryldialkylphosphatase    8.5      -
# 10496   3.1.8.1                        aryldialkylphosphatase   10.5      -
# 10497   3.1.8.1                        aryldialkylphosphatase   10.5      -
# 10498   3.1.8.1                        aryldialkylphosphatase   10.5      -
# 10499   3.1.8.1                        aryldialkylphosphatase   10.5      -
# 10500   3.1.8.1                        aryldialkylphosphatase   10.5      -
# 10503   3.1.8.2                 diisopropyl-fluorophosphatase      8      -
# 10504   3.1.8.2                 diisopropyl-fluorophosphatase      8      -
#
#                                                 comments      organism  \
# 9203                                            assay at  Homo sapiens
# 9204                                            assay at  Homo sapiens
# 9208                                            assay at  Homo sapiens
# 9209                                            assay at  Homo sapiens
# 9210                                            assay at  Homo sapiens
# 9213                                            assay at  Homo sapiens
# 9214                                            assay at  Homo sapiens
# 9215                                            assay at  Homo sapiens
# 9216                                            assay at  Homo sapiens
# 9221                                            assay at  Homo sapiens
# 9222                                            assay at  Homo sapiens
# 9272                                            assay at  Homo sapiens
# 9669                                            assay at  Homo sapiens
# 10451                                           assay at  Homo sapiens
# 10452                                           assay at  Homo sapiens
# 10454                                           assay at  Homo sapiens
# 10457                                                  -  Homo sapiens
# 10461                                           assay at  Homo sapiens
# 10462                                           assay at  Homo sapiens
# 10463                                           assay at  Homo sapiens
# 10464                                           assay at  Homo sapiens
# 10465                                           assay at  Homo sapiens
# 10466                                           assay at  Homo sapiens
# 10467                                           assay at  Homo sapiens
# 10478                                           assay at  Homo sapiens
# 10480                                           assay at  Homo sapiens
# 10481                                           assay at  Homo sapiens
# 10496                                           assay at  Homo sapiens
# 10497                                           assay at  Homo sapiens
# 10498                                           assay at  Homo sapiens
# 10499  paraoxonase activity of recombinant PON1-hFc o...  Homo sapiens
# 10500  the maximum rate of methylphosphonic acid hydr...  Homo sapiens
# 10503                                           assay at  Homo sapiens
# 10504                                           assay at  Homo sapiens
#
#       uniprot_id                                                ref
# 9203      P27169                      35213, 665028, 678376, 681730
# 9204      P27169                      35213, 665028, 678376, 681730
# 9208      P27169  35212, 35215, 663985, 664184, 665960, 677411, ...
# 9209      P27169  35212, 35215, 663985, 664184, 665960, 677411, ...
# 9210      P27169  35212, 35215, 663985, 664184, 665960, 677411, ...
# 9213      P27169  35212, 35215, 663985, 664184, 665960, 677411, ...
# 9214      P27169  35212, 35215, 663985, 664184, 665960, 677411, ...
# 9215      P27169  35212, 35215, 663985, 664184, 665960, 677411, ...
# 9216      P27169  35212, 35215, 663985, 664184, 665960, 677411, ...
# 9221      P27169                                     677892, 679634
# 9222      P27169                                     677892, 679634
# 9272      P27169                                             665960
# 9669      P27169                                             749628
# 10451     P27169                      35213, 678376, 679759, 681730
# 10452     P27169                      35213, 678376, 679759, 681730
# 10454     P27169                                             749610
# 10457     P27169                             664153, 666426, 707214
# 10461     P27169  35212, 663614, 664184, 665987, 677411, 677893,...
# 10462     P27169  35212, 663614, 664184, 665987, 677411, 677893,...
# 10463     P27169  35212, 663614, 664184, 665987, 677411, 677893,...
# 10464     P27169  35212, 663614, 664184, 665987, 677411, 677893,...
# 10465     P27169  35212, 663614, 664184, 665987, 677411, 677893,...
# 10466     P27169  35212, 663614, 664184, 665987, 677411, 677893,...
# 10467     P27169  35212, 663614, 664184, 665987, 677411, 677893,...
# 10478     P27169                             665960, 677892, 679634
# 10480     P27169                             665960, 677892, 679634
# 10481     P27169                             665960, 677892, 679634
# 10496     P27169       35208, 35215, 664184, 677884, 678464, 681055
# 10497     P27169       35208, 35215, 664184, 677884, 678464, 681055
# 10498     P27169       35208, 35215, 664184, 677884, 678464, 681055
# 10499     P27169                                             752102
# 10500     P27169                                             749684
# 10503     P27169                                     749628, 752102
# 10504     P27169                                     749628, 752102

# %%
out_file = Path(data_dir, "ph_opt/20230907_ph_opt_processed.csv")
data_uniprot.to_csv(out_file, index=False)

# %% [markdown]
# Remove the "assay at" rows as well as the mutant rows (for now)

# %%
print(len(data_uniprot), data_uniprot.uniprot_id.nunique())
data_uniprot = data_uniprot[data_uniprot.comments.apply(lambda x: "assay at" not in x)]
print(len(data_uniprot), data_uniprot.uniprot_id.nunique())
# Out:
# 24674 15793
# 14049 9819

# %%
print(len(data_uniprot), data_uniprot.uniprot_id.nunique())
data_uniprot = data_uniprot[data_uniprot.comments.apply(lambda x: "mutant" not in x)]
print(len(data_uniprot), data_uniprot.uniprot_id.nunique())
# Out:
# 14049 9819
# 13781 9763

# %%
out_file = Path(data_dir, "ph_opt/20230907_ph_opt_no_assay_at_no_mutant.csv")
data_uniprot.drop(columns='name').to_csv(out_file, index=False)

# %% [markdown]
# ### Match the data_opt rows with the ph_range rows
# - We should be able to match based on the references

# %%
out_file = Path(data_dir, "ph_range/20230907_ph_range_processed_act.csv")
data_act_ph_range = pd.read_csv(out_file)
print(len(data_act_ph_range))
data_act_ph_range

out_file = Path(data_dir, "ph_range/20230907_ph_range_processed.csv")
data_ph_range = pd.read_csv(out_file, index_col=0)
data_ph_range = data_ph_range[data_ph_range.index.isin(data_act_ph_range.exp_index.unique())]
print(len(data_ph_range))
# Out:
# 6241
# 3151

# %%
data_act_ph_range
# Out:
#       exp_index    ph  activity                note  \
# 0             1   4.0      0.80                 NaN
# 1             1   7.5      0.60                 NaN
# 2             3   4.9      0.25  reduction reaction
# 3             3   5.8      0.40  reduction reaction
# 4             4   4.9      0.25  reduction reaction
# ...         ...   ...       ...                 ...
# 6234        240  10.0      0.60                 NaN
# 6235        240  11.0      1.00                 NaN
# 6236        232   5.0      1.00                 NaN
# 6237        232   4.0      0.60                 NaN
# 6238        232   8.0      0.60                 NaN
#
#                                        ph_range_comment  uniprot_id
# 0     pH 4.0: about 80% of maximal activity, pH 7.5:...      B2KJ46
# 1     pH 4.0: about 80% of maximal activity, pH 7.5:...      B2KJ46
# 2     pH 4.9: about 25% of maximal activity, pH 5.8:...      Q4J702
# 3     pH 4.9: about 25% of maximal activity, pH 5.8:...      Q4J702
# 4     pH 4.9: about 25% of maximal activity, pH 5.8:...      Q4J9F2
# ...                                                 ...         ...
# 6234  over 60% of maximal activity within this range...  A0A141BGH5
# 6235  over 60% of maximal activity within this range...  A0A141BGH5
# 6236  over 60% of maximal activity within this range...  A0A141BGH5
# 6237  over 60% of maximal activity within this range...  A0A141BGH5
# 6238  over 60% of maximal activity within this range...  A0A141BGH5
#
# [6239 rows x 6 columns]

# %%
data_ph_range
# Out:
#         ec_num                               name ph_min ph_max  \
# 1      1.1.1.1              alcohol dehydrogenase      4    7.5
# 3      1.1.1.1              alcohol dehydrogenase    4.9    5.8
# 4      1.1.1.1              alcohol dehydrogenase    4.9    5.8
# 5      1.1.1.1              alcohol dehydrogenase    5.5    7.5
# 7      1.1.1.1              alcohol dehydrogenase      6      -
# ...        ...                                ...    ...    ...
# 6382   6.5.1.7       DNA ligase (ATP, ADP or GTP)    6.5      9
# 6391   7.1.2.2  H+-transporting two-sector ATPase     10      -
# 6392  7.2.2.10            P-type Ca2+ transporter    5.5      8
# 6393  7.2.2.10            P-type Ca2+ transporter    5.5      8
# 6395  7.2.2.19            H+/K+-exchanging ATPase    6.8    7.8
#
#                                                comments  \
# 1     pH 4.0: about 80% of maximal activity, pH 7.5:...
# 3     pH 4.9: about 25% of maximal activity, pH 5.8:...
# 4     pH 4.9: about 25% of maximal activity, pH 5.8:...
# 5     pH 5.5: about 35% of maximal activity, pH 7.5:...
# 7     50% of maximum activity for reduction of aldeh...
# ...                                                 ...
# 6382  pH 6.5: about 90% of maximal activity, 9.0: ab...
# 6391  ATP synthesis in washed membranes of Haloferax...
# 6392  about 35% of maximal activity at pH 5.5 and at...
# 6393  about 35% of maximal activity at pH 5.5 and at...
# 6395  pH 6.8: about 60% of maximal activity, pH 7.8:...
#
#                        organism uniprot_id     ref
# 1          Candida parapsilosis     B2KJ46  684556
# 3     Sulfolobus acidocaldarius     Q4J702  719428
# 4     Sulfolobus acidocaldarius     Q4J9F2  719428
# 5       Sulfurisphaera tokodaii     F9VMI9  718627
# 7     Thermococcus kodakarensis     Q5JI09  735486
# ...                         ...        ...     ...
# 6382     Hyperthermus butylicus     A2BJX6  727438
# 6391         Haloferax volcanii     Q48332  727822
# 6392   Saccharomyces cerevisiae     P13586  210495
# 6393   Saccharomyces cerevisiae     P38929  210495
# 6395                 Sus scrofa     P19156  246853
#
# [3151 rows x 8 columns]

# %%
data_opt_match = data_uniprot[data_uniprot.uniprot_id.isin(data_ph_range.uniprot_id.unique())]
print(len(data_opt_match))
data_opt_match.head(2)
# Out:
# 3181
#     ec_num                   name ph_min ph_max                comments  \
# 0  1.1.1.1  alcohol dehydrogenase      3      -  reduction of aldehydes
# 1  1.1.1.1  alcohol dehydrogenase    4.5      -                       -
#
#                     organism uniprot_id     ref ph_range_ref_match
# 0  Thermococcus kodakarensis     Q5JI09  735486             735486
# 1       Candida parapsilosis     B2KJ46  684556             684556

# %%
ph_range_refs = set([r.strip() for refs in data_ph_range.ref.values for r in refs.split(',')])
print(len(ph_range_refs))
# Out:
# 2276

# %%
# use the reference to matchup the optimum rather than the uniprot ID
def match_refs(refs):
    if not isinstance(refs, str):
        return np.nan
    for r in refs.replace(' ','').split(','):
        if r in ph_range_refs:
            return r
    return np.nan

data_uniprot['ph_range_ref_match'] = data_uniprot.ref.apply(match_refs)
data_opt_match = data_uniprot.dropna(subset='ph_range_ref_match')
print(len(data_opt_match))
data_opt_match.head(2)
# Out:
# 2751
#     ec_num                   name ph_min ph_max                comments  \
# 0  1.1.1.1  alcohol dehydrogenase      3      -  reduction of aldehydes
# 1  1.1.1.1  alcohol dehydrogenase    4.5      -                       -
#
#                     organism uniprot_id     ref ph_range_ref_match
# 0  Thermococcus kodakarensis     Q5JI09  735486             735486
# 1       Candida parapsilosis     B2KJ46  684556             684556

# %%
data_opt_match.head(2)
# Out:
#     ec_num                   name ph_min ph_max                comments  \
# 0  1.1.1.1  alcohol dehydrogenase      3      -  reduction of aldehydes
# 1  1.1.1.1  alcohol dehydrogenase    4.5      -                       -
#
#                     organism uniprot_id     ref ph_range_ref_match
# 0  Thermococcus kodakarensis     Q5JI09  735486             735486
# 1       Candida parapsilosis     B2KJ46  684556             684556

# %%
data_act_ph_range.head(2)
# Out:
#    exp_index   ph  activity note  \
# 0          1  4.0       0.8  NaN
# 1          1  7.5       0.6  NaN
#
#                                     ph_range_comment uniprot_id
# 0  pH 4.0: about 80% of maximal activity, pH 7.5:...     B2KJ46
# 1  pH 4.0: about 80% of maximal activity, pH 7.5:...     B2KJ46

# %%
data_act_ph_range[data_act_ph_range.exp_index == 6265]
# Out:
#       exp_index   ph  activity  \
# 3676       6265  6.0      0.21
# 3677       6265  7.0      0.21
#
#                                                    note  \
# 3676  3.1% and in the presence of 1 mM and 0.5 mM Mn...
# 3677  3.1% and in the presence of 1 mM and 0.5 mM Mn...
#
#                                        ph_range_comment uniprot_id
# 3676  3.1% and 21% of maximal activity at pH 6.0 and...     Q49W02
# 3677  3.1% and 21% of maximal activity at pH 6.0 and...     Q49W02

# %%
data_ph_range.loc[6265].comments
# Out:
# '3.1% and 21% of maximal activity at pH 6.0 and pH 7.0 in the presence of 1 mM and 0.5 mM Mn2+, respectively'

# %%
# Match the ph optimum to the correct ph range
opt_not_in_range = []
matched_data = []
matched_more_than_2_count = 0
for exp_idx, df in data_act_ph_range.groupby("exp_index"):
    note = df.note.unique()[0]
    row = data_ph_range.loc[exp_idx]
    df2 = data_opt_match[(data_opt_match.ref == row.ref) & 
                         (data_opt_match.uniprot_id == row.uniprot_id) & 
                         (data_opt_match.ec_num == row.ec_num)]
    if len(df2) == 0:
        continue
    if len(df2) > 1:
        matched_more_than_2_count += 1
    #     # skip for now
    #     continue
    # ph_opts = [ph for phs in df2.opt.values for ph in phs.split('-')]
    # ph_opts = list(df2.ph_min.values)
    # ph_opts += [ph for ph in df2.ph_max.values if ph != '-']
    for ph_min, ph_max, note in df2[['ph_min', 'ph_max', 'comments']].values:
        ph_opts = [float(ph_min)]
        if ph_max != '-':
            ph_opts += [float(ph_max)]
        for ph_opt in ph_opts:
            if len(df) == 1 or (
                df.ph.min() < ph_opt and df.ph.max() > ph_opt):
                # ph_opt is in range. Add to data
                matched_data += [[exp_idx, ph_opt, 1.0, note, row.uniprot_id]]
            else:
                print(df[['exp_index', 'ph', 'activity', 'note']].values, ph_opts, note)
                opt_not_in_range.append((exp_idx, ph_opts))
                continue
print(f"{len(matched_data) = }, {len(opt_not_in_range) = }, {matched_more_than_2_count = }")
# Out:
# [[3 4.9 0.25 'reduction reaction']
#  [3 5.8 0.4 'reduction reaction']] [8.2] oxidation of alcohols
# [[3 4.9 0.25 'reduction reaction']
#  [3 5.8 0.4 'reduction reaction']] [8.2] oxidation reaction
# [[4 4.9 0.25 'reduction reaction']
#  [4 5.8 0.4 'reduction reaction']] [8.2] oxidation of alcohols
# [[4 4.9 0.25 'reduction reaction']
#  [4 5.8 0.4 'reduction reaction']] [8.2] oxidation reaction
# [[5 5.5 0.35 'reduction of benzaldehyde']
#  [5 7.5 0.55 'reduction of benzaldehyde']] [10.5] oxidation of 1-hexanol
# [[10 8.5 0.85 'oxidation reaction']
#  [10 6.7 0.4 'oxidation reaction']] [5.1] reduction of ketones
# [[10 8.5 0.85 'oxidation reaction']
#  [10 6.7 0.4 'oxidation reaction']] [5.1] reduction reaction
# [[11 6.7 0.4 'oxidation reaction']
#  [11 8.5 0.85 'oxidation reaction']] [5.1] reduction of ketones
# [[11 6.7 0.4 'oxidation reaction']
#  [11 8.5 0.85 'oxidation reaction']] [5.1] reduction reaction
# [[13 7.0 0.7 'reduction of 2-pentanone']
#  [13 9.6 0.5 'reduction of 2-pentanone']] [10.5] oxidation of 2-pentanol
# [[15 7.5 0.35 'oxidation of 1-hexanol']
#  [15 10.8 0.5 'oxidation of 1-hexanol']] [7.0] reduction of benzaldehyde
# [[16 11.5 0.3 'oxidation of 2-pentanol']
#  [16 9.5 0.4 'oxidation of 2-pentanol']] [8.0] reduction of 2-pentanone
# [[22 7.0 0.8
#   'reduction of D-xylulose with NADH, within this range, recombinant His-tagged enzyme']
#  [22 3.0 0.8
#   'reduction of D-xylulose with NADH, within this range, recombinant His-tagged enzyme']] [8.5] oxidation of D-arabitol with NAD+, recombinant His-tagged enzyme
# [[23 11.0 0.6
#   'oxidation of D-arabitol with NAD+, within this range, recombinant His-tagged enzyme']
#  [23 6.0 0.6
#   'oxidation of D-arabitol with NAD+, within this range, recombinant His-tagged enzyme']] [5.5] reduction of D-xylulose with NADH, recombinant His-tagged enzyme
# [[43 6.0 0.4 nan]
#  [43 8.0 0.4 nan]] [6.0, 7.0] -
# [[89 6.7 0.8 nan]
#  [89 9.0 0.8 nan]] [10.0, 11.0] alcohol oxidation
# [[89 6.7 0.8 nan]
#  [89 9.0 0.8 nan]] [10.0, 11.0] alcohol oxidation
# [[97 7.0 0.8 'for reduction of aldehyde']
#  [97 8.5 0.8 'for reduction of aldehyde']] [10.5] oxidation of alcohol
# [[122 6.0 0.95 'reduction reaction']
#  [122 4.5 0.1 'reduction reaction']
#  [122 7.5 0.1 'reduction reaction']] [9.5] oxidation reaction
# [[123 7.5 0.5 'reduction reaction']
#  [123 9.0 0.0 'reduction reaction']
#  [123 5.0 0.25 'reduction reaction']] [9.5] oxidation reaction, recombinant enzyme
# [[124 9.5 0.95 'oxidation reaction']
#  [124 10.5 0.1 'oxidation reaction']] [5.5, 6.0] recombinant enzyme, reduction reaction
# [[124 9.5 0.95 'oxidation reaction']
#  [124 10.5 0.1 'oxidation reaction']] [5.5, 6.0] recombinant enzyme, reduction reaction
# [[124 9.5 0.95 'oxidation reaction']
#  [124 10.5 0.1 'oxidation reaction']] [9.5] oxidation reaction, recombinant enzyme
# [[128 5.5 0.4 'reduction of D-ribulose']
#  [128 8.5 0.1 'reduction of D-ribulose']] [8.5] oxidation of D-arabitol
# [[131 4.0 0.4 'for reduction of pyruvate within this range']
#  [131 8.0 0.4 'for reduction of pyruvate within this range']] [8.5, 9.5] oxidation of lactate
# [[131 4.0 0.4 'for reduction of pyruvate within this range']
#  [131 8.0 0.4 'for reduction of pyruvate within this range']] [8.5, 9.5] oxidation of lactate
# [[132 4.0 0.0 nan]
#  [132 10.0 0.0 nan]] [11.5] recombinant enzyme, lactate oxidation
# [[134 8.0 0.2 'oxidation of lactate']
#  [134 8.5 0.9 'oxidation of lactate']
#  [134 9.0 0.95 'oxidation of lactate']
#  [134 9.5 0.95 'oxidation of lactate']
#  [134 7.5 0.0 'oxidation of lactate']] [5.0, 5.5] reduction of pyruvate
# [[134 8.0 0.2 'oxidation of lactate']
#  [134 8.5 0.9 'oxidation of lactate']
#  [134 9.0 0.95 'oxidation of lactate']
#  [134 9.5 0.95 'oxidation of lactate']
#  [134 7.5 0.0 'oxidation of lactate']] [5.0, 5.5] reduction of pyruvate
# [[134 8.0 0.2 'oxidation of lactate']
#  [134 8.5 0.9 'oxidation of lactate']
#  [134 9.0 0.95 'oxidation of lactate']
#  [134 9.5 0.95 'oxidation of lactate']
#  [134 7.5 0.0 'oxidation of lactate']] [8.5, 9.5] oxidation of lactate
# [[145 9.0 0.95 'L-HSE oxidation']
#  [145 7.0 0.011 'L-HSE oxidation']] [9.0] L-HSE oxidation in the presence of 0.4 M NaCl
# [[153 8.0 0.8 'free cells']
#  [153 7.0 0.8 'free cells']] [8.0] recombinant enzyme
# [[155 9.0 0.95 nan]
#  [155 10.0 0.95 nan]
#  [155 6.5 0.05 nan]] [9.0, 10.0] activity decreases rapidly with decreasing pH. At pH 6.5 the enzyme is almost inactive
# [[164 11.0 0.55 nan]
#  [164 9.0 0.45 nan]] [5.5, 6.5] conversion of acetoacetyl-CoA to beta-hydroxybutyryl-CoA decreases above pH 6.5
# [[164 11.0 0.55 nan]
#  [164 9.0 0.45 nan]] [5.5, 6.5] conversion of acetoacetyl-CoA to beta-hydroxybutyryl-CoA decreases above pH 6.5
# [[175 6.5 0.85 'reduction of acetoin']
#  [175 7.0 0.85 'reduction of acetoin']] [6.5] for acetoin reduction
# [[175 6.5 0.85 'reduction of acetoin']
#  [175 7.0 0.85 'reduction of acetoin']] [10.0] for (2R,3R)-butane-2,3-diol oxidation
# [[181 7.3 0.65 'pH: pH: recombinant NADP-ME3']
#  [181 8.3 0.65 'pH: pH: recombinant NADP-ME3']
#  [181 7.3 0.65 'pH: pH: recombinant NADP-ME3']
#  [181 8.3 0.65 'pH: pH: recombinant NADP-ME3']] [7.3] recombinant NADP-ME2
# [[182 7.3 0.65 'pH: pH: recombinant NADP-ME3']
#  [182 8.3 0.65 'pH: pH: recombinant NADP-ME3']
#  [182 7.3 0.65 'pH: pH: recombinant NADP-ME3']
#  [182 8.3 0.65 'pH: pH: recombinant NADP-ME3']] [7.3] recombinant NADP-ME2
# [[191 7.5 1.0 nan]
#  [191 5.8 0.33 nan]] [7.5] -
# [[194 6.5 0.6 'isoenzyme IDP1']
#  [194 9.0 0.7 'isoenzyme IDP1']] [6.5, 9.0] more than 90% of optimal Vmax, isoenzyme IDP2
# [[194 6.5 0.6 'isoenzyme IDP1']
#  [194 9.0 0.7 'isoenzyme IDP1']] [6.5, 9.0] more than 90% of optimal Vmax, isoenzyme IDP2
# [[195 6.5 0.6 'isoenzyme IDP1']
#  [195 9.0 0.7 'isoenzyme IDP1']] [6.5, 9.0] more than 90% of optimal Vmax, isoenzyme IDP2
# [[195 6.5 0.6 'isoenzyme IDP1']
#  [195 9.0 0.7 'isoenzyme IDP1']] [6.5, 9.0] more than 90% of optimal Vmax, isoenzyme IDP2
# [[196 7.0 0.6 'isoenzyme IDP2']
#  [196 8.0 0.4 'isoenzyme IDP2']] [8.0] isoenzyme IDP1
# [[196 7.0 0.6 'isoenzyme IDP2']
#  [196 8.0 0.4 'isoenzyme IDP2']] [8.5] isoenzyme IDP3
# [[197 7.0 0.6 'isoenzyme IDP2']
#  [197 8.0 0.4 'isoenzyme IDP2']] [8.0] isoenzyme IDP1
# [[197 7.0 0.6 'isoenzyme IDP2']
#  [197 8.0 0.4 'isoenzyme IDP2']] [8.5] isoenzyme IDP3
# [[200 7.5 0.9 nan]
#  [200 8.5 0.9 nan]] [8.5] -
# [[244 7.5 0.75 nan]
#  [244 9.5 0.75 nan]] [5.2] enzyme possess a dual pH optimum. A significant decrease in the Ki for substrate inhibition at pH values corresponding to the valley between these optima is responsible for this phenomenon
# [[255 6.0 0.6 nan]
#  [255 8.0 0.6 nan]] [9.0] -
# [[291 6.0 0.95 nan]
#  [291 7.0 0.95 nan]] [6.0, 7.0] the enzyme activity retains more than 95% of its maximal activity within the pH range of 6-7 at 25°C
# [[291 6.0 0.95 nan]
#  [291 7.0 0.95 nan]] [6.0, 7.0] the enzyme activity retains more than 95% of its maximal activity within the pH range of 6-7 at 25°C
# [[305 6.0 0.95 nan]
#  [305 7.5 0.95 nan]
#  [305 5.0 0.0 nan]] [6.0, 7.5] recombinant His-tagged enzyme
# [[321 3.2 0.5 'reaction with cellobiose and cytochrome c']
#  [321 5.3 0.45 'reaction with cellobiose and cytochrome c']] [4.5, 7.5] two activity peaks, one at pH 3.5 and another at pH 4.5-4.75, the activity at pH 3.5 is 90% of the activity at pH 4.5-7.5, reaction with cellobiose and cytochrome c
# [[346 7.0 0.55
#   "substrate: 2,2'-azino-bis(3-ethylbenzothiazoline-6-sulfonic acid)"]
#  [346 4.0 0.35
#   "substrate: 2,2'-azino-bis(3-ethylbenzothiazoline-6-sulfonic acid)"]] [7.0] substrate: 2,6-dimethoxyphenol
# [[353 6.0 0.75 'substrate: 2,6-dimethoxyphenol']
#  [353 9.0 0.5 'substrate: 2,6-dimethoxyphenol']] [5.5] substrate: 2,2'-azino-bis(3-ethylbenzothiazoline-6-sulfonic acid)
# [[381 9.0 0.95 nan]
#  [381 5.4 0.0 nan]] [9.0] -
# [[388 4.0 0.534 nan]
#  [388 3.0 0.184 nan]] [5.0, 10.0] broad optimum
# [[388 4.0 0.534 nan]
#  [388 3.0 0.184 nan]] [5.0, 10.0] broad optimum
# [[392 4.5 0.9 'above']
#  [392 10.5 0.9 'above']] [10.5] -
# [[450 8.0 0.3 nan]
#  [450 9.0 0.15 nan]] [6.0] -
# [[472 6.0 0.5 'within this range']
#  [472 9.0 0.5 'within this range']] [6.0, 7.5] broad optimum
# [[479 10.0 0.1 'almost no activity at pH 4.5, i.e. a second optima']
#  [479 8.0 0.7 'almost no activity at pH 4.5, i.e. a second optima']] [6.0, 6.5] -
# [[479 10.0 0.1 'almost no activity at pH 4.5, i.e. a second optima']
#  [479 8.0 0.7 'almost no activity at pH 4.5, i.e. a second optima']] [6.0, 6.5] -
# [[582 6.0 0.5 'within this range']
#  [582 9.0 0.5 'within this range']] [6.0, 7.5] broad optimum
# [[628 7.6 0.95 nan]
#  [628 7.8 0.95 nan]] [7.0] -
# [[628 7.6 0.95 nan]
#  [628 7.8 0.95 nan]] [7.0] broad optimum
# [[669 6.6 0.1 nan]
#  [669 7.0 0.0 nan]] [6.0] activity assay, feruloyl-CoA as substrate
# [[762 7.0 0.7 nan]
#  [762 8.5 0.7 nan]] [7.0] -
# [[810 6.5 0.35 'reduction of oxidized coenzyme F420 with NADPH']
#  [810 4.5 0.45 'reduction of oxidized coenzyme F420 with NADPH']] [8.0] reduction of NADP+ with reduced coenzyme F420
# [[811 7.0 0.6 'reduction of NADP+ with reduced coenzyme F420']
#  [811 9.0 0.5 'reduction of NADP+ with reduced coenzyme F420']] [5.5] reduction of oxidized coenzyme F420 with NADPH
# [[812 7.5 0.5 'reduction of NADP+ with reduced coenzyme F420']
#  [812 10.0 0.9 'reduction of NADP+ with reduced coenzyme F420']] [5.5] pH optimum for reduction of oxidized coenzyme F420 with NADPH
# [[815 5.0 0.4 nan]
#  [815 11.0 0.8 nan]] [4.0, 6.0] substrates: DELTA1-pyrroline-2-carboxylate + NADH + H+
# [[815 5.0 0.4 nan]
#  [815 11.0 0.8 nan]] [11.0] substrates: L-proline + NAD+
# [[816 12.0 0.85 nan]
#  [816 10.0 0.75 nan]] [4.0, 6.0] substrates: DELTA1-pyrroline-2-carboxylate + NADH + H+
# [[816 12.0 0.85 nan]
#  [816 10.0 0.75 nan]] [4.0, 6.0] substrates: DELTA1-pyrroline-2-carboxylate + NADH + H+
# [[826 7.0 0.6 'substrate: spermine']
#  [826 9.0 0.45 'substrate: spermine']] [6.5] substrate: thermospermine
# [[838 5.0 0.5 nan]
#  [838 8.0 0.5 nan]] [8.0] -
# [[839 5.0 0.5 nan]
#  [839 8.0 0.5 nan]] [8.0] -
# [[841 6.5 0.55 nan]
#  [841 9.0 0.55 nan]] [6.5] -
# [[842 6.5 0.55 nan]
#  [842 9.0 0.55 nan]] [6.5] -
# [[861 8.0 0.95 nan]
#  [861 9.0 0.95 nan]] [7.0] quinone reductase activity
# [[873 6.0 0.95 'inferred']
#  [873 7.0 0.95 'inferred']] [6.0] -
# [[903 4.5 0.7 nan]
#  [903 5.5 0.35 nan]] [4.5, 5.0] -
# [[904 5.5 0.35 nan]
#  [904 4.5 0.7 nan]] [4.5, 5.0] -
# [[960 7.5 0.95 nan]
#  [960 9.0 0.95 nan]] [7.5] -
# [[979 5.0 0.8 'native enzyme,within this range']
#  [979 6.0 0.8 'native enzyme,within this range']] [5.0] native enzyme
# [[979 5.0 0.8 'native enzyme,within this range']
#  [979 6.0 0.8 'native enzyme,within this range']] [6.0] recombinant enzyme
# [[981 6.3 0.8 'recombinant enzyme,within this range']
#  [981 5.4 0.8 'recombinant enzyme,within this range']] [5.0] native enzyme
# [[1023 1.0 0.0 nan]
#  [1023 3.0 0.0 nan]] [7.5, 8.5] -
# [[1023 1.0 0.0 nan]
#  [1023 3.0 0.0 nan]] [7.5, 8.5] -
# [[1024 9.5 0.05 'inferred']
#  [1024 10.0 0.05 'inferred']] [7.5, 8.5] -
# [[1024 9.5 0.05 'inferred']
#  [1024 10.0 0.05 'inferred']] [7.5, 8.5] -
# [[1032 6.5 0.9 nan]
#  [1032 7.5 0.9 nan]
#  [1032 8.0 0.5 nan]
#  [1032 9.0 0.1 nan]] [6.5, 7.5] recombinant enzyme, broad optimum
# [[1053 10.0 1.0 'L-gamma-glutamyl-4-nitroanilide with diglycine acceptor']
#  [1053 9.0 0.96 nan]
#  [1053 8.0 0.926 nan]
#  [1053 6.0 0.25 nan]] [10.0] -
# [[1069 8.5 0.8 'within this range']
#  [1069 6.0 0.8 'within this range']] [8.0, 8.5] maximum activity
# [[1086 5.5 0.4 nan]
#  [1086 7.5 0.4 nan]] [5.5] -
# [[1089 5.5 0.4 nan]
#  [1089 7.5 0.4 nan]] [5.0] -
# [[1158 5.0 0.5 nan]
#  [1158 7.0 0.5 nan]] [7.0, 7.5] -
# [[1158 5.0 0.5 nan]
#  [1158 7.0 0.5 nan]] [7.0, 7.5] -
# [[1159 5.0 0.5 nan]
#  [1159 7.0 0.5 nan]] [7.0, 7.5] -
# [[1159 5.0 0.5 nan]
#  [1159 7.0 0.5 nan]] [7.0, 7.5] -
# [[1160 8.0 0.5 nan]
#  [1160 6.5 0.5 nan]] [6.0, 6.5] -
# [[1160 8.0 0.5 nan]
#  [1160 6.5 0.5 nan]] [6.0, 6.5] -
# [[1161 6.5 0.5 nan]
#  [1161 8.0 0.5 nan]] [6.0, 6.5] -
# [[1161 6.5 0.5 nan]
#  [1161 8.0 0.5 nan]] [6.0, 6.5] -
# [[1229 6.0 0.5 'glycosynthesis']
#  [1229 7.0 0.5 'glycosynthesis']] [6.0] glycosynthesis
# [[1229 6.0 0.5 'glycosynthesis']
#  [1229 7.0 0.5 'glycosynthesis']] [7.0, 7.5] phosphorolysis
# [[1229 6.0 0.5 'glycosynthesis']
#  [1229 7.0 0.5 'glycosynthesis']] [7.0, 7.5] phosphorolysis
# [[1251 5.0 0.95 nan]
#  [1251 6.0 0.95 nan]] [6.0] recombinant enzyme
# [[1298 8.5 1.0 nan]
#  [1298 7.5 0.6 nan]] [8.5] -
# [[1365 8.0 0.5 'phosphoserine synthesis']
#  [1365 9.0 0.6 'phosphoserine synthesis']] [9.0] phosphoserine synthesis
# [[1394 5.0 0.5 nan]
#  [1394 7.0 0.65 nan]] [7.0] -
# [[1394 5.0 0.5 nan]
#  [1394 7.0 0.65 nan]] [7.0] -
# [[1394 5.0 0.5 nan]
#  [1394 7.0 0.65 nan]] [7.0] glucokinase activity
# [[1394 5.0 0.5 nan]
#  [1394 7.0 0.65 nan]] [7.0] glucokinase activity
# [[1395 5.0 0.5 nan]
#  [1395 7.0 0.65 nan]] [7.0] -
# [[1395 5.0 0.5 nan]
#  [1395 7.0 0.65 nan]] [7.0] -
# [[1395 5.0 0.5 nan]
#  [1395 7.0 0.65 nan]] [7.0] glucokinase activity
# [[1395 5.0 0.5 nan]
#  [1395 7.0 0.65 nan]] [7.0] glucokinase activity
# [[1451 4.0 0.9 nan]
#  [1451 10.0 0.9 nan]] [4.0, 10.0] -
# [[1451 4.0 0.9 nan]
#  [1451 10.0 0.9 nan]] [4.0, 10.0] -
# [[1550 5.5 0.7 'maximal activity in 50 mM potassium phosphate buffer']
#  [1550 8.0 0.2 'maximal activity in 50 mM potassium phosphate buffer']] [8.0] maximal activity in 50 mM Tris-HCl buffer
# [[1551 6.5 0.65 'potassium phosphate buffer']
#  [1551 9.2 0.2 'potassium phosphate buffer']] [6.5] potassium phosphate buffer
# [[1552 6.5 0.65 'potassium phosphate buffer']
#  [1552 9.2 0.2 'potassium phosphate buffer']] [6.5] potassium phosphate buffer
# [[1559 7.0 0.7 'in 50 mM Tris-HCl buffer']
#  [1559 9.5 0.7 'in 50 mM Tris-HCl buffer']] [6.0] maximal activity in 50 mM potassium phosphate buffer
# [[1649 1.0 0.5 'inferred']
#  [1649 3.0 0.5 'inferred']
#  [1649 4.0 0.25 'inferred']
#  [1649 7.0 0.01 nan]] [8.0] two pH optima, pH 2.0 and pH 8.0, are recorded
# [[1651 4.0 0.8 'recombinant enzyme, within this range']
#  [1651 5.0 0.8 'recombinant enzyme, within this range']] [5.0] recombinant enzyme
# [[1677 5.0 0.55 nan]
#  [1677 7.0 0.37 nan]] [9.0] -
# [[1717 3.0 0.96 nan]
#  [1717 5.0 0.96 nan]] [3.0] -
# [[1731 6.0 0.6 'within this range']
#  [1731 7.0 0.6 'within this range']] [7.0] -
# [[1732 6.0 0.6 'within this range']
#  [1732 7.0 0.6 'within this range']] [7.0] -
# [[1733 6.0 0.6 'within this range']
#  [1733 7.0 0.6 'within this range']] [7.0] -
# [[1734 6.0 0.6 'within this range']
#  [1734 7.0 0.6 'within this range']] [7.0] -
# [[1735 7.0 0.6 'within this range']
#  [1735 6.0 0.6 'within this range']] [7.0] -
# [[1736 6.0 0.6 'within this range']
#  [1736 7.0 0.6 'within this range']] [7.0] -
# [[1744 7.0 0.6 'within this range']
#  [1744 8.0 0.6 'within this range']] [7.0] -
# [[1745 8.0 0.6 'within this range']
#  [1745 7.0 0.6 'within this range']] [7.0] -
# [[1746 7.0 0.6 'within this range']
#  [1746 8.0 0.6 'within this range']] [7.0] -
# [[1747 7.0 0.6 'within this range']
#  [1747 8.0 0.6 'within this range']] [7.0] -
# [[1748 7.0 0.6 'within this range']
#  [1748 8.0 0.6 'within this range']] [7.0] -
# [[1749 8.0 0.6 'within this range']
#  [1749 7.0 0.6 'within this range']] [7.0] -
# [[1768 4.1 0.0 nan]
#  [1768 8.0 1.0 nan]
#  [1768 4.5 0.1 nan]] [8.0] -
# [[1790 5.5 0.25 nan]
#  [1790 6.5 0.25 nan]] [6.5] -
# [[1791 5.5 0.25 nan]
#  [1791 6.5 0.25 nan]] [6.5] -
# [[1794 6.0 0.86 nan]
#  [1794 9.0 0.86 nan]] [7.5, 9.0] -
# [[1880 6.0 0.5 nan]
#  [1880 8.0 0.5 nan]] [6.0] -
# [[1922 7.1 0.85
#   'hydrolysis of 1-phosphatidyl-1D-myo-inositol 4,5-bisphosphate']
#  [1922 7.6 0.65
#   'hydrolysis of 1-phosphatidyl-1D-myo-inositol 4,5-bisphosphate']] [8.0] hydrolysis of phosphatidylinositol
# [[1949 10.5 1.0 nan]
#  [1949 7.5 0.0 nan]] [10.5] paraoxonase activity of recombinant PON1-hFc or PON1
# [[2031 4.0 0.85 'alpha-1,4-glycosidic linkage hydrolysis of maltotriose']
#  [2031 6.0 0.6 'alpha-1,4-glycosidic linkage hydrolysis of maltotriose']] [6.0] alpha-1,6-glycosidic linkage hydrolysis
# [[2055 4.5 0.9 nan]
#  [2055 6.0 0.9 nan]] [4.5] -
# [[2102 6.0 0.8 'within this range']
#  [2102 4.0 0.8 'within this range']] [6.0] -
# [[2103 6.0 0.8 'within this range']
#  [2103 4.0 0.8 'within this range']] [6.0] -
# [[2104 4.0 0.8 'within this range']
#  [2104 6.0 0.8 'within this range']] [6.0] -
# [[2132 3.3 0.7 "substrate: N,N',N''-triacetyl chitotrioside"]
#  [2132 4.7 0.5 "substrate: N,N',N''-triacetyl chitotrioside"]] [4.7] substrate: N,N',N''-triacetylchitotrioside
# [[2159 6.0 0.6 'alpha-1,4-glycosidic linkage hydrolysis of maltotriose']
#  [2159 4.0 0.85 'alpha-1,4-glycosidic linkage hydrolysis of maltotriose']] [6.0] alpha-1,6-glycosidic linkage hydrolysis
# [[2163 1.0 0.45 nan]
#  [2163 4.0 0.55 nan]] [3.5, 4.0] -
# [[2164 1.0 0.45 nan]
#  [2164 4.0 0.55 nan]] [3.5, 4.0] -
# [[2165 1.0 0.45 nan]
#  [2165 4.0 0.55 nan]] [3.5, 4.0] -
# [[2170 2.5 0.4 nan]
#  [2170 5.5 0.4 nan]] [2.0] -
# [[2170 2.5 0.4 nan]
#  [2170 5.5 0.4 nan]] [2.5, 3.0] -
# [[2171 2.5 0.4 nan]
#  [2171 5.5 0.4 nan]] [2.0] -
# [[2171 2.5 0.4 nan]
#  [2171 5.5 0.4 nan]] [2.5, 3.0] -
# [[2172 5.5 0.4 nan]
#  [2172 2.5 0.4 nan]] [2.0] -
# [[2172 5.5 0.4 nan]
#  [2172 2.5 0.4 nan]] [2.5, 3.0] -
# [[2175 3.5 0.8 'recombinant His-tagged enzyme, in this range']
#  [2175 5.0 0.8 'recombinant His-tagged enzyme, in this range']] [3.5] recombinant His-tagged enzyme
# [[2189 5.0 0.8 nan]
#  [2189 3.5 0.8 nan]] [3.5] -
# [[2194 5.0 0.7 'beta-glucosidase TpBGL3']
#  [2194 3.0 0.65 'beta-glucosidase TpBGL3']] [6.0] beta-glucosidase TpBGL1
# [[2195 3.0 0.65 'beta-glucosidase TpBGL3']
#  [2195 5.0 0.7 'beta-glucosidase TpBGL3']] [6.0] beta-glucosidase TpBGL1
# [[2206 4.0 0.45 'beta-glucosidase TpBGL1']
#  [2206 8.0 0.6 'beta-glucosidase TpBGL1']] [4.0] beta-glucosidase TpBGL3
# [[2207 4.0 0.45 'beta-glucosidase TpBGL1']
#  [2207 8.0 0.6 'beta-glucosidase TpBGL1']] [4.0] beta-glucosidase TpBGL3
# [[2219 6.5 0.6 'substrate: 4-nitrophenyl beta-D-glucopyranoside']
#  [2219 5.0 0.3 'substrate: 4-nitrophenyl beta-D-glucopyranoside']] [5.0, 5.5] with 4-nitrophenyl beta-D-glucopyranoside as substrate
# [[2220 5.0 0.3 'substrate: 4-nitrophenyl beta-D-glucopyranoside']
#  [2220 6.5 0.6 'substrate: 4-nitrophenyl beta-D-glucopyranoside']] [5.0, 5.5] with 4-nitrophenyl beta-D-glucopyranoside as substrate
# [[2221 5.0 0.3 'substrate: 4-nitrophenyl beta-D-glucopyranoside']
#  [2221 6.5 0.6 'substrate: 4-nitrophenyl beta-D-glucopyranoside']] [5.0, 5.5] with 4-nitrophenyl beta-D-glucopyranoside as substrate
# [[2222 5.0 0.9 'substrate: 4-nitrophenyl beta-D-glucopyranoside']
#  [2222 6.5 0.7 'substrate: 4-nitrophenyl beta-D-glucopyranoside']] [5.0, 5.5] with 4-nitrophenyl beta-D-glucopyranoside as substrate
# [[2223 5.0 0.9 'substrate: 4-nitrophenyl beta-D-glucopyranoside']
#  [2223 6.5 0.7 'substrate: 4-nitrophenyl beta-D-glucopyranoside']] [5.0, 5.5] with 4-nitrophenyl beta-D-glucopyranoside as substrate
# [[2224 6.5 0.7 'substrate: 4-nitrophenyl beta-D-glucopyranoside']
#  [2224 5.0 0.9 'substrate: 4-nitrophenyl beta-D-glucopyranoside']] [5.0, 5.5] with 4-nitrophenyl beta-D-glucopyranoside as substrate
# [[2232 7.0 0.8 nan]
#  [2232 8.5 0.8 nan]] [7.0] -
# [[2250 6.5 0.9 'in the pH range of 6.5-8.5']
#  [2250 8.5 0.9 'in the pH range of 6.5-8.5']] [6.5] -
# [[2255 2.0 0.9 'recombinant His-tagged isozyme betafruct2, % at pH 4.5']
#  [2255 4.5 0.2 nan]] [4.0, 5.0] recombinant His-tagged isozyme betafruct3
# [[2256 4.5 0.2 'recombinant His-tagged isozyme betafruct']
#  [2256 2.0 0.9 'recombinant His-tagged isozyme betafruct']] [4.0, 5.0] recombinant His-tagged isozyme betafruct3
# [[2257 2.0 0.9 'recombinant His-tagged isozyme betafruct2, % at pH 4.5']
#  [2257 4.5 0.2 nan]] [4.0, 5.0] recombinant His-tagged isozyme betafruct3
# [[2261 3.5 0.5 'recombinant His-tagged isozyme betafruct3,']
#  [2261 6.0 0.5 'recombinant His-tagged isozyme betafruct3,']] [3.0] recombinant His-tagged isozyme betafruct2
# [[2262 3.5 0.5 'recombinant His-tagged isozyme betafruct3,']
#  [2262 6.0 0.5 'recombinant His-tagged isozyme betafruct3,']] [3.0] recombinant His-tagged isozyme betafruct2
# [[2263 3.5 0.5 'recombinant His-tagged isozyme betafruct3,']
#  [2263 6.0 0.5 'recombinant His-tagged isozyme betafruct3,']] [3.0] recombinant His-tagged isozyme betafruct2
# [[2270 6.0 0.5 nan]
#  [2270 9.0 0.7 nan]] [6.0, 7.5] -
# [[2318 7.0 0.8 'within']
#  [2318 6.0 0.8 'within']] [7.0] substrate 4-nitrophenyl alpha-L-arabinofuranoside
# [[2322 7.0 0.6 nan]
#  [2322 9.0 0.6 nan]] [7.0] -
# [[2356 4.5 0.45
#   'chimeric fusion protein CelA-SSO1949-CelA, that consists of 70 amino acids CelA followed by 163 amino acids SSO1949 and 29 amino acids CelA']
#  [2356 3.5 0.7
#   'chimeric fusion protein CelA-SSO1949-CelA, that consists of 70 amino acids CelA followed by 163 amino acids SSO1949 and 29 amino acids CelA']] [3.0] chimeric fusion protein CelA-SSO1949-CelA, that consists of 70 amino acids CelA followed by 163 amino acids SSO1949 and 29 amino acids CelA
# [[2356 4.5 0.45
#   'chimeric fusion protein CelA-SSO1949-CelA, that consists of 70 amino acids CelA followed by 163 amino acids SSO1949 and 29 amino acids CelA']
#  [2356 3.5 0.7
#   'chimeric fusion protein CelA-SSO1949-CelA, that consists of 70 amino acids CelA followed by 163 amino acids SSO1949 and 29 amino acids CelA']] [3.0] hybrid protein (CelA-SSO1949-CelA) based on beta-endoglucanase from Sulfolobus solfataricus P2 and beta-endoglucanase from Thermotoga maritima
# [[2357 4.5 0.45
#   'chimeric fusion protein CelA-SSO1949-CelA, that consists of 70 amino acids CelA followed by 163 amino acids SSO1949 and 29 amino acids CelA']
#  [2357 3.5 0.7
#   'chimeric fusion protein CelA-SSO1949-CelA, that consists of 70 amino acids CelA followed by 163 amino acids SSO1949 and 29 amino acids CelA']] [3.0] chimeric fusion protein CelA-SSO1949-CelA, that consists of 70 amino acids CelA followed by 163 amino acids SSO1949 and 29 amino acids CelA
# [[2357 4.5 0.45
#   'chimeric fusion protein CelA-SSO1949-CelA, that consists of 70 amino acids CelA followed by 163 amino acids SSO1949 and 29 amino acids CelA']
#  [2357 3.5 0.7
#   'chimeric fusion protein CelA-SSO1949-CelA, that consists of 70 amino acids CelA followed by 163 amino acids SSO1949 and 29 amino acids CelA']] [4.5] native enzyme
# [[2392 4.0 0.5 nan]
#  [2392 7.9 0.5 nan]] [7.9] -
# [[2393 4.0 0.5 nan]
#  [2393 7.9 0.5 nan]] [7.9] -
# [[2402 5.0 0.5 nan]
#  [2402 8.7 0.5 nan]] [5.0, 6.9] -
# [[2403 8.7 0.5 nan]
#  [2403 5.0 0.5 nan]] [5.0, 6.9] -
# [[2444 4.0 0.8 nan]
#  [2444 6.0 0.8 nan]] [8.0] -
# [[2510 5.5 0.7 'within']
#  [2510 1.0 0.7 'within']] [11.5] -
# [[2589 7.0 0.7 'recombinant enzyme, within this range']
#  [2589 9.0 0.7 'recombinant enzyme, within this range']] [6.5, 8.5] recombinant enzyme
# [[2597 5.0 0.8 'isoform 1-FEH I shows']
#  [2597 6.0 0.8 'isoform 1-FEH I shows']] [6.0] -
# [[2598 6.0 0.8 'isoform 1-FEH I shows']
#  [2598 5.0 0.8 'isoform 1-FEH I shows']] [6.0] -
# [[2610 4.0 0.8 'in comparison to the activity at ph 4.0']
#  [2610 7.0 0.8 'in comparison to the activity at ph 4.0']] [4.0] -
# [[2618 5.0 0.5 nan]
#  [2618 7.0 0.5 nan]] [5.0] -
# [[2618 5.0 0.5 nan]
#  [2618 7.0 0.5 nan]] [5.0] pH optimum using Avicel or cellotetraose as substrates
# [[2620 5.0 0.3
#   'optimum at pH 5, drop of activity between pH 6 and pH 7 to']
#  [2620 7.0 0.3
#   'optimum at pH 5, drop of activity between pH 6 and pH 7 to']] [5.0] -
# [[2625 6.0 0.8 'retains']
#  [2625 9.0 0.8 'retains']] [6.0] optimum pH of the enzyme for Galbeta1-3GalNAcalpha1-pNP hydrolysis is at pH 6.0 and 9.0, whereas optimum pH for other substrates hydrolyzed is around pH 6.0
# [[2645 5.5 0.8 nan]
#  [2645 6.5 0.6 nan]] [5.5] -
# [[2646 6.0 0.6 'alpha-1,4-glycosidic linkage hydrolysis of maltotriose']
#  [2646 4.0 0.85 'alpha-1,4-glycosidic linkage hydrolysis of maltotriose']] [6.0] alpha-1,6-glycosidic linkage hydrolysis
# [[2663 8.0 0.45 'native enzyme,, inactive at pH 5.0 and 9.0']
#  [2663 6.0 0.45 'native enzyme,, inactive at pH 5.0 and 9.0']] [8.0] recombinant enzyme
# [[2670 7.5 0.4 'recombinant enzyme,']
#  [2670 9.0 0.75 'recombinant enzyme,']] [7.0] native enzyme
# [[2767 7.5 0.55 nan]
#  [2767 8.0 0.75 nan]] [7.5] -
# [[2801 7.0 0.9 'within this range, profile overview']
#  [2801 9.0 0.9 'within this range, profile overview']] [9.0] -
# [[2819 4.0 0.5
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B2']
#  [2819 6.0 0.7
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B2']] [4.5, 6.0] substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4
# [[2820 4.0 0.5
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B2']
#  [2820 6.0 0.7
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B2']] [4.5, 6.0] substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4
# [[2821 4.0 0.5
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B2']
#  [2821 6.0 0.7
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B2']] [4.5, 6.0] substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4
# [[2822 6.0 0.8
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B3']
#  [2822 4.0 0.55
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B3']] [4.5, 6.0] substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4
# [[2823 4.0 0.55
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B3']
#  [2823 6.0 0.8
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B3']] [4.5, 6.0] substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4
# [[2824 4.0 0.55
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B3']
#  [2824 6.0 0.8
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B3']] [4.5, 6.0] substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4
# [[2825 4.0 0.6
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4']
#  [2825 6.0 0.5
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4']] [4.5, 6.0] substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4
# [[2826 4.0 0.6
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4']
#  [2826 6.0 0.5
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4']] [4.5, 6.0] substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4
# [[2827 6.0 0.5
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4']
#  [2827 4.0 0.6
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4']] [4.5, 6.0] substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4
# [[2828 4.0 0.7
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B1']
#  [2828 6.0 0.8
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B1']] [4.5, 6.0] substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4
# [[2829 4.0 0.7
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B1']
#  [2829 6.0 0.8
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B1']] [4.5, 6.0] substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4
# [[2830 4.0 0.7
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B1']
#  [2830 6.0 0.8
#   'substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B1']] [4.5, 6.0] substrate: benzyloxycarbonyl-Phe-Arg-7-amido-4-methylcoumarin, cathepsin B4
# [[2928 5.0 0.0 'about 20% activity at pH 2.0, 100% activity at pH 3.0,']
#  [2928 4.0 0.8 'about 20% activity at pH 2.0, 100% activity at pH 3.0,']] [3.0] -
# [[3001 8.0 0.5 '112 kDa CDase from kidney,in the range']
#  [3001 9.0 0.5 '112 kDa CDase from kidney,in the range']] [6.0, 7.0] 112 kDa CDase from kidney
# [[3001 8.0 0.5 '112 kDa CDase from kidney,in the range']
#  [3001 9.0 0.5 '112 kDa CDase from kidney,in the range']] [6.0, 7.0] 112 kDa CDase from kidney
# [[3019 5.0 0.7 nan]
#  [3019 9.0 0.7 nan]] [9.0] -
# [[3092 6.0 0.8 nan]
#  [3092 8.0 0.8 nan]] [8.0] -
# [[3105 8.3 0.65 'pH: pH: recombinant NADP-ME3']
#  [3105 7.3 0.65 'pH: pH: recombinant NADP-ME3']] [7.0] soluble and enzyme ecapsulated in ethyleneamine-mediated biosilica
# [[3151 7.5 0.6 nan]
#  [3151 9.0 0.9 nan]] [8.5, 9.0] -
# [[3152 7.5 0.6 nan]
#  [3152 9.0 0.9 nan]] [8.5, 9.0] -
# [[3208 8.0 0.3 nan]
#  [3208 5.5 1.0 nan]] [5.5] recombinant enzyme
# [[3209 8.8 0.3 'soluble wild-type enzyme']
#  [3209 6.2 0.95 'soluble wild-type enzyme']
#  [3209 8.0 0.95 'soluble wild-type enzyme']] [6.2, 8.0] broad optimum, soluble wild-type enzyme
# [[3271 9.5 0.75 'retro-aldol addition']
#  [3271 6.0 0.65 'retro-aldol addition']] [6.0] aldol addition
# [[3348 4.0 0.6 nan]
#  [3348 6.0 0.6 nan]] [7.0] -
# [[3478 7.0 0.8
#   'substrate: apo-[phycoerythrocyanin beta-subunit] mutant C155']
#  [3478 7.0 0.8
#   'substrate: apo-[phycoerythrocyanin beta-subunit] mutant C155']] [7.0, 9.0] substrate: apo-[C-phycocyanin beta-subunit]
# [[3478 7.0 0.8
#   'substrate: apo-[phycoerythrocyanin beta-subunit] mutant C155']
#  [3478 7.0 0.8
#   'substrate: apo-[phycoerythrocyanin beta-subunit] mutant C155']] [7.0, 9.0] substrate: apo-[C-phycocyanin beta-subunit]
# [[3571 5.0 0.6 nan]
#  [3571 7.5 0.6 nan]] [7.5] -
# [[3596 8.0 0.9 nan]
#  [3596 9.0 0.9 nan]] [7.5] -
# [[3611 4.0 0.5 nan]
#  [3611 6.0 0.5 nan]] [6.0] -
# [[3613 7.0 0.22 '2% and, respectively, at 1 mM Mn2+']
#  [3613 6.0 0.22 '2% and, respectively, at 1 mM Mn2+']] [8.0] -
# [[3666 8.0 0.95 nan]
#  [3666 9.0 0.95 nan]
#  [3666 7.0 0.8 nan]] [8.0, 9.0] -
# [[3667 6.0 0.6 'at pH 6.0-7.0, the recombinant enzyme shows 15–']
#  [3667 7.0 0.6 'at pH 6.0-7.0, the recombinant enzyme shows 15–']] [6.0] forward reaction
# [[3667 6.0 0.6 'at pH 6.0-7.0, the recombinant enzyme shows 15–']
#  [3667 7.0 0.6 'at pH 6.0-7.0, the recombinant enzyme shows 15–']] [7.0] reverse reaction
# [[3667 6.0 0.6 'at pH 6.0-7.0, the recombinant enzyme shows 15–']
#  [3667 7.0 0.6 'at pH 6.0-7.0, the recombinant enzyme shows 15–']] [8.0] -
# [[3669 7.0 0.2 'at pH 9,  at pH 9']
#  [3669 8.0 0.65 'at pH 9,  at pH 9']] [9.0] or above. At a pH of above 9 the coupled spectrophotometric assay becomes limited due to instability of the substrates
# [[3673 7.0 0.2 'at pH 9,  at pH 9']
#  [3673 8.0 0.65 'at pH 9,  at pH 9']] [9.0] or above. At a pH of above 9 the coupled spectrophotometric assay becomes limited due to instability of the substrates
# [[3744 11.5 0.85 'ethanol oxidation enzyme form ADH-3']
#  [3744 9.5 0.4 'ethanol oxidation enzyme form ADH-3']] [6.5] reduction of octanal
# [[3745 11.0 0.75 'pyrazole-insensitive enzyme']
#  [3745 10.0 0.5 'pyrazole-insensitive enzyme']] [11.2] oxidation of ethanol, pyrazole-sensitive enzyme form
# [[3754 6.0 0.5 'above and below, sugar reduction']
#  [3754 7.2 0.5 'above and below, sugar reduction']] [6.0, 7.2] D-fructose reduction
# [[3754 6.0 0.5 'above and below, sugar reduction']
#  [3754 7.2 0.5 'above and below, sugar reduction']] [6.0, 7.2] D-fructose reduction
# [[3754 6.0 0.5 'above and below, sugar reduction']
#  [3754 7.2 0.5 'above and below, sugar reduction']] [11.0] sorbitol oxidation
# [[3755 9.2 0.5 'above and below, sorbitol oxidation']
#  [3755 11.6 0.5 'above and below, sorbitol oxidation']] [6.0, 7.2] D-fructose reduction
# [[3755 9.2 0.5 'above and below, sorbitol oxidation']
#  [3755 11.6 0.5 'above and below, sorbitol oxidation']] [6.0, 7.2] D-fructose reduction
# [[3795 6.5 0.5 nan]
#  [3795 8.0 0.5 nan]
#  [3795 4.5 0.0 nan]
#  [3795 7.5 1.0 nan]] [9.8] -
# [[3801 5.8 0.5 ', formation of (7S)-salutaridinol']
#  [3801 7.8 0.5 ', formation of (7S)-salutaridinol']] [9.0, 9.5] formation of salutaridine
# [[3801 5.8 0.5 ', formation of (7S)-salutaridinol']
#  [3801 7.8 0.5 ', formation of (7S)-salutaridinol']] [9.0, 9.5] formation of salutaridine
# [[3802 5.8 0.5 ', formationof salutaridine']
#  [3802 7.8 0.5 ', formationof salutaridine']] [9.0, 9.5] formation of salutaridine
# [[3802 5.8 0.5 ', formationof salutaridine']
#  [3802 7.8 0.5 ', formationof salutaridine']] [9.0, 9.5] formation of salutaridine
# [[3804 8.5 0.6 nan]
#  [3804 8.0 0.4 nan]
#  [3804 10.0 0.95 nan]
#  [3804 11.0 0.95 nan]] [10.0, 11.0] oxidation of D-arabinitol
# [[3805 4.2 0.4 nan]
#  [3805 6.5 0.3 nan]] [7.5] oxidation of scytalone
# [[3806 7.0 0.95 nan]
#  [3806 8.0 0.8 nan]] [5.5] reduction of 1,3,6,8-tetrahydroxynaphthalene
# [[3811 8.0 0.6 'reduction of pyruvate']
#  [3811 5.3 0.5 'reduction of pyruvate']] [9.8] oxidation of lactate
# [[3812 8.5 0.6 'oxidation of lactate']
#  [3812 10.7 0.7 'oxidation of lactate']] [7.0] reduction of pyruvate
# [[3822 7.5 0.5 nan]
#  [3822 4.5 0.55 nan]] [8.9] xylitol oxidation
# [[3849 5.5 0.3 'isoform ICD-1,isoform ICD-2,']
#  [3849 5.5 0.1 'isoform ICD-1,isoform ICD-2,']] [7.5] both isoforms ICD-1, ICD-2
# [[3850 5.5 0.1 'isoform ICD-1,isoform ICD-2,']
#  [3850 5.5 0.3 'isoform ICD-1,isoform ICD-2,']] [7.5] both isoforms ICD-1, ICD-2
# [[3855 9.5 0.9 'isoform ICD-1,isoform ICD-2,']
#  [3855 9.5 0.4 'isoform ICD-1,isoform ICD-2,']] [7.5] both isoforms ICD-1, ICD-2
# [[3856 9.5 0.9 'isoform ICD-1,isoform ICD-2,']
#  [3856 9.5 0.4 'isoform ICD-1,isoform ICD-2,']] [7.5] both isoforms ICD-1, ICD-2
# [[3874 5.5 0.7 'reduction of dihydroxyacetone']
#  [3874 9.0 0.45 'reduction of dihydroxyacetone']] [5.0, 6.0] reduction of dihydroxyacetone
# [[3874 5.5 0.7 'reduction of dihydroxyacetone']
#  [3874 9.0 0.45 'reduction of dihydroxyacetone']] [11.0, 12.0] oxidation of glycerol
# [[3874 5.5 0.7 'reduction of dihydroxyacetone']
#  [3874 9.0 0.45 'reduction of dihydroxyacetone']] [11.0, 12.0] oxidation of glycerol
# [[3875 9.0 0.45 'oxidation of glycerol']
#  [3875 11.0 0.95 'oxidation of glycerol']
#  [3875 12.0 0.95 'oxidation of glycerol']] [5.0, 6.0] reduction of dihydroxyacetone
# [[3875 9.0 0.45 'oxidation of glycerol']
#  [3875 11.0 0.95 'oxidation of glycerol']
#  [3875 12.0 0.95 'oxidation of glycerol']] [5.0, 6.0] reduction of dihydroxyacetone
# [[3875 9.0 0.45 'oxidation of glycerol']
#  [3875 11.0 0.95 'oxidation of glycerol']
#  [3875 12.0 0.95 'oxidation of glycerol']] [11.0, 12.0] oxidation of glycerol
# [[4033 8.0 0.7 'NADH-dehydrogenase']
#  [4033 7.0 0.7 'NADH-dehydrogenase']] [5.0] NADH-dehydrogenase
# [[4034 8.0 0.7 'NADH-dehydrogenase']
#  [4034 7.0 0.7 'NADH-dehydrogenase']] [5.0] NADH-dehydrogenase
# [[4126 7.0 0.9 'methylmalonate semialdehyde oxidation, above and below']
#  [4126 8.5 0.9 'methylmalonate semialdehyde oxidation, above and below']] [9.0] propanal + NAD+
# [[4128 8.0 0.5 'propanal oxidation, above and below']
#  [4128 9.5 0.5 'propanal oxidation, above and below']] [8.0] 2-methyl-3-oxopropanoate + CoA + NAD+
# [[4270 5.5 0.5 ', tauropine formation, enzyme form TaDH-1']
#  [4270 7.9 0.5 ', tauropine formation, enzyme form TaDH-1']] [8.5] tauropine oxidation
# [[4271 6.8 0.5 'tauropine oxidation, enzyme form TaDH-1']
#  [4271 8.5 1.0 'tauropine oxidation, enzyme form TaDH-1']] [6.6, 7.3] tauropine formation, enzyme form TaDH-1
# [[4271 6.8 0.5 'tauropine oxidation, enzyme form TaDH-1']
#  [4271 8.5 1.0 'tauropine oxidation, enzyme form TaDH-1']] [8.5] tauropine oxidation
# [[4409 6.0 0.6 'cytosol: about 70% at 8.5, mitochondria: and 8.5']
#  [4409 6.0 0.4 'cytosol: about 70% at 8.5, mitochondria: and 8.5']] [7.3] -
# [[4410 6.0 0.6 'cytosol: about 70% at 8.5, mitochondria: and 8.5']
#  [4410 6.0 0.4 'cytosol: about 70% at 8.5, mitochondria: and 8.5']] [7.3] -
# [[4567 7.6 0.95 'pH 7.3-7.no activity below pH 6.7']
#  [4567 7.3 0.95 'pH 7.3-7.no activity below pH 6.7']
#  [4567 6.6 0.0 'pH 7.3-7.no activity below pH 6.7']] [7.3, 7.6] -
# [[4568 8.2 0.5 'and sucrose cleavage']
#  [4568 5.0 0.9 'and sucrose cleavage']] [9.5] sucrose synthesis
# [[4571 10.0 0.9 'and sucrose synthesis']
#  [4571 7.5 0.5 'and sucrose synthesis']] [6.0] sucrose cleavage
# [[4586 6.5 0.6 'more than 90% between pH 8.0, and 11.0']
#  [4586 7.0 0.8 'more than 90% between pH 8.0, and 11.0']
#  [4586 7.5 1.0 'more than 90% between pH 8.0, and 11.0']] [7.5] -
# [[4587 6.5 0.6 'more than 90% between pH 8.0, and 11.0']
#  [4587 7.0 0.8 'more than 90% between pH 8.0, and 11.0']
#  [4587 7.5 1.0 'more than 90% between pH 8.0, and 11.0']] [7.5] -
# [[4645 7.3 0.55 nan]
#  [4645 6.4 0.5 nan]] [6.2] -
# [[4671 7.2 0.5 'maximum,  maximum']
#  [4671 8.0 0.7 'maximum,  maximum']] [7.5, 8.0] -
# [[4782 6.0 0.8 nan]
#  [4782 9.5 0.8 nan]] [10.0] -
# [[4824 5.0 0.6 'at least']
#  [4824 7.0 0.6 'at least']] [8.0, 8.5] -
# [[4824 5.0 0.6 'at least']
#  [4824 7.0 0.6 'at least']] [8.0, 8.5] -
# [[4839 5.0 0.5 ', pyridoxine as substrate']
#  [4839 6.0 0.5 ', pyridoxine as substrate']] [6.0] substrate 2-methyl-4-amino-5-hydroxymethylpyrimidine
# [[4864 7.5 0.5 'maximum, pH 8.4 and  maximum']
#  [4864 9.4 0.85 'maximum, pH 8.4 and  maximum']] [5.5] substrate DNA
# [[4865 7.5 0.5 'maximum, pH 8.4 and  maximum']
#  [4865 9.4 0.85 'maximum, pH 8.4 and  maximum']] [5.5] substrate DNA
# [[4905 5.0 0.3 'ATP synthesis']
#  [4905 8.2 0.3 'ATP synthesis']] [8.3] synthesis of N-phospho-L-arginine
# [[4906 5.5 0.9 'no activity at pH 5.0, synthesis of ATP']
#  [4906 8.0 0.7 'no activity at pH 5.0, synthesis of ATP']] [9.0] synthesis of N-phospho-L-arginine
# [[4908 8.0 0.6 'synthesis of N-phospho-L-Arg']
#  [4908 10.0 0.7 'synthesis of N-phospho-L-Arg']] [6.1] synthesis of ATP
# [[4924 5.2 0.5 nan]
#  [4924 7.5 0.5 nan]] [7.5] -
# [[4925 5.7 0.5 ', dGMP-phosphorylation, calf thymus']
#  [4925 10.9 0.5 ', dGMP-phosphorylation, calf thymus']] [7.0, 10.9] GMP-phosphorylation
# [[4928 5.0 0.45 nan]
#  [4928 6.0 0.95 nan]
#  [4928 9.0 0.95 nan]] [6.0, 9.0] -
# [[5017 6.0 0.75 nan]
#  [5017 7.0 1.0 nan]] [7.0] with substrate 4-nitrophenyl 2-O-(methyl 4-O-methyl-alpha-D-glucopyranosyluronate)-beta-D-xylopyranoside
# [[5022 6.5 0.5 nan]
#  [5022 5.9 0.0 nan]
#  [5022 7.5 0.95 nan]
#  [5022 9.0 0.95 nan]] [7.5, 9.0] -
# [[5040 5.8 0.5 nan]
#  [5040 8.0 0.6 nan]] [5.5, 8.0] -
# [[5040 5.8 0.5 nan]
#  [5040 8.0 0.6 nan]] [5.5, 8.0] -
# [[5041 5.8 0.5 nan]
#  [5041 8.0 0.6 nan]] [5.5, 8.0] -
# [[5041 5.8 0.5 nan]
#  [5041 8.0 0.6 nan]] [5.5, 8.0] -
# [[5101 6.8 0.6 'enzyme form H-2']
#  [5101 8.4 0.35 'enzyme form H-2']] [8.4] enzyme form H-1
# [[5102 6.8 0.6 'enzyme form H-2']
#  [5102 8.4 0.35 'enzyme form H-2']] [8.4] enzyme form H-1
# [[5103 7.5 0.45 ', enzyme form H-1']
#  [5103 9.0 0.45 ', enzyme form H-1']] [7.5] enzyme form H-2
# [[5104 7.5 0.45 ', enzyme form H-1']
#  [5104 9.0 0.45 ', enzyme form H-1']] [7.5] enzyme form H-2
# [[5176 5.0 0.2 'enzyme from animals without infection']
#  [5176 7.0 0.55 'enzyme from animals without infection']] [7.0] enzyme from animals infected with Schistosoma mansoni
# [[5185 7.5 0.1 'below']
#  [5185 6.0 0.1 'below']] [8.5] -
# [[5229 5.5 0.5 ', in the presence of soybean phosphatidylinositol']
#  [5229 7.5 0.5 ', in the presence of soybean phosphatidylinositol']] [5.5, 6.5] in the presence of egg yolk lyso-phosphatidylcholine
# [[5925 8.8 0.95 'hydrolysis of 2-hydroxy-dATP']
#  [5925 7.2 0.6 'hydrolysis of 2-hydroxy-dATP']] [7.7, 8.8] hydrolysis of 2-hydroxy-dATP
# [[5926 7.2 0.15 'hydrolysis of 8-oxo-dGTP']
#  [5926 7.7 0.95 'hydrolysis of 8-oxo-dGTP']
#  [5926 8.8 0.5 'hydrolysis of 8-oxo-dGTP']] [7.7, 8.8] hydrolysis of 2-hydroxy-dATP
# [[6069 6.8 0.5 'wild-type enzyme, above and below']
#  [6069 8.0 0.5 'wild-type enzyme, above and below']] [8.0] enzyme expressed in Escherichia coli
# [[6194 3.3 0.95 nan]
#  [6194 4.4 0.95 nan]
#  [6194 5.2 0.75 nan]
#  [6194 5.7 0.0 nan]] [3.0, 4.4] -
# [[6221 6.5 0.1 nan]
#  [6221 10.0 0.95 nan]
#  [6221 8.0 0.95 nan]] [8.0, 10.0] -
# [[6233 10.0 0.3 nan]
#  [6233 6.0 0.35 nan]] [8.0, 10.0] -
# [[6241 6.3 0.5 nan]
#  [6241 7.0 0.5 nan]] [6.3] -
# [[6264 6.0 0.24
#   '24% and in the presence of 1 mM and 0.5 mM Mn2+, respectively']
#  [6264 7.0 0.36
#   '24% and in the presence of 1 mM and 0.5 mM Mn2+, respectively']] [8.0] -
# [[6265 6.0 0.03
#   '3.1% and in the presence of 1 mM and 0.5 mM Mn2+, respectively']
#  [6265 7.0 0.21
#   '3.1% and in the presence of 1 mM and 0.5 mM Mn2+, respectively']] [8.0] -
# [[6335 7.0 0.1 '8.4-8.9: maximal activity']
#  [6335 8.0 0.75 '8.4-8.9: maximal activity']] [8.4, 8.9] -
# [[6335 7.0 0.1 '8.4-8.9: maximal activity']
#  [6335 8.0 0.75 '8.4-8.9: maximal activity']] [8.4, 8.9] -
# [[6350 7.4 0.9 nan]
#  [6350 8.1 0.9 nan]] [4.7] -
# [[6361 5.5 0.6 nan]
#  [6361 7.0 0.6 nan]] [7.5, 7.8] reaction of ATP + citrulline + L-argininosuccinate
# [[6361 5.5 0.6 nan]
#  [6361 7.0 0.6 nan]] [7.5, 7.8] reaction of ATP + citrulline + L-argininosuccinate
# [[6362 6.5 0.55 'reaction of ATP + citrulline + L-argininosuccinate']
#  [6362 8.5 0.7 'reaction of ATP + citrulline + L-argininosuccinate']] [6.0, 6.5] reaction of AMP + diphosphate + L-argininosuccinate
# [[6362 6.5 0.55 'reaction of ATP + citrulline + L-argininosuccinate']
#  [6362 8.5 0.7 'reaction of ATP + citrulline + L-argininosuccinate']] [6.0, 6.5] reaction of AMP + diphosphate + L-argininosuccinate
# [[6364 7.8 0.4 'with NH4+ as amide donor']
#  [6364 9.3 0.5 'with NH4+ as amide donor']] [6.2, 8.4] broad peak of activity with a maximum around 7.6, with Gln as the amide donor
# [[6378 7.2 0.95 nan]
#  [6378 7.7 0.95 nan]
#  [6378 8.4 0.5 nan]] [7.2, 7.7] in Tris-HCl buffer
# len(matched_data) = 3242, len(opt_not_in_range) = 336, matched_more_than_2_count = 434

# %%
# some manual match fixes
exp_idx_matches_to_fix = [6335, 6265, 6264]
for exp_idx in exp_idx_matches_to_fix:
    row = data_ph_range.loc[exp_idx]
    df2 = data_opt_match[(data_opt_match.ref == row.ref) & 
                         (data_opt_match.uniprot_id == row.uniprot_id) & 
                         (data_opt_match.ec_num == row.ec_num)]
    for ph_min, ph_max, note in df2[['ph_min', 'ph_max', 'comments']].values:
        ph_opts = [float(ph_min)]
        if ph_max != '-':
            ph_opts += [float(ph_max)]
        for ph_opt in ph_opts:
            matched_data += [[exp_idx, ph_opt, 1.0, note, row.uniprot_id]]

# %%
matched_ph_opts = pd.DataFrame(matched_data, columns=['exp_index', 'ph', 'activity', 'note', 'uniprot_id'])
print(len(matched_ph_opts))
matched_ph_opts
# Out:
# 3246
#       exp_index   ph  activity                  note uniprot_id
# 0             1  4.5       1.0                     -     B2KJ46
# 1             3  5.1       1.0  reduction of ketones     Q4J702
# 2             3  5.1       1.0    reduction reaction     Q4J702
# 3             4  5.1       1.0  reduction of ketones     Q4J9F2
# 4             4  5.1       1.0    reduction reaction     Q4J9F2
# ...         ...  ...       ...                   ...        ...
# 3241       6393  6.7       1.0                     -     P38929
# 3242       6335  8.4       1.0                     -     Q53005
# 3243       6335  8.9       1.0                     -     Q53005
# 3244       6265  8.0       1.0                     -     Q49W02
# 3245       6264  8.0       1.0                     -     P39773
#
# [3246 rows x 5 columns]

# %%
data_act2 = pd.concat([data_act_ph_range, matched_ph_opts], ignore_index=True).reset_index(drop=True)
data_act2.sort_values('exp_index', inplace=True)
print(len(data_act_ph_range), len(data_act2))
# print(data_act2.uniprot_id.nunique(), len(data_act2))
data_act2.head(10)
# Out:
# 6241 9487
#       exp_index   ph  activity                  note  \
# 0             1  4.0      0.80                   NaN
# 1             1  7.5      0.60                   NaN
# 6241          1  4.5      1.00                     -
# 6243          3  5.1      1.00    reduction reaction
# 6242          3  5.1      1.00  reduction of ketones
# 3             3  5.8      0.40    reduction reaction
# 2             3  4.9      0.25    reduction reaction
# 5             4  5.8      0.40    reduction reaction
# 6245          4  5.1      1.00    reduction reaction
# 6244          4  5.1      1.00  reduction of ketones
#
#                                        ph_range_comment uniprot_id
# 0     pH 4.0: about 80% of maximal activity, pH 7.5:...     B2KJ46
# 1     pH 4.0: about 80% of maximal activity, pH 7.5:...     B2KJ46
# 6241                                                NaN     B2KJ46
# 6243                                                NaN     Q4J702
# 6242                                                NaN     Q4J702
# 3     pH 4.9: about 25% of maximal activity, pH 5.8:...     Q4J702
# 2     pH 4.9: about 25% of maximal activity, pH 5.8:...     Q4J702
# 5     pH 4.9: about 25% of maximal activity, pH 5.8:...     Q4J9F2
# 6245                                                NaN     Q4J9F2
# 6244                                                NaN     Q4J9F2

# %%
print(data_act2[data_act2.ph > 13])
print(data_act2[data_act2.ph < 1])
# Out:
# Empty DataFrame
# Columns: [exp_index, ph, activity, note, ph_range_comment, uniprot_id]
# Index: []
# Empty DataFrame
# Columns: [exp_index, ph, activity, note, ph_range_comment, uniprot_id]
# Index: []

# %%
data_act2 = data_act2.drop_duplicates()

# %%
# write to file
out_file = Path(data_dir, "ph_range/20230907_ph_range_processed_act_wopt.csv")
print(out_file)
data_act2.to_csv(out_file, index=False)
# Out:
# /projects/robustmicrob/jlaw/projects/prot_stability_engineering/inputs/brenda/ph_range/20230907_ph_range_processed_act_wopt.csv
